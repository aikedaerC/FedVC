# %%
import paddle
import numpy as np
import paddle.nn as nn
from paddle.vision.datasets import Cifar10 as CIFAR10
from paddle.vision.datasets import Cifar100 as CIFAR100
from paddle.vision.datasets import MNIST
from paddle.vision import transforms
from paddle import optimizer as optim
import paddle.nn.functional as F

import os
import logging
from paddle.io import DataLoader

logging.basicConfig()
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
class Swish(nn.Layer):  # Swish(x) = x∗σ(x)
    def __init__(self):
        super().__init__()

    def forward(self, input):
        return input * F.sigmoid(input)


class ConvNet(nn.Layer):
    def __init__(self, channel=3, num_classes=10, net_width=128, net_depth=3, net_act='relu', net_norm='instancenorm',
                 net_pooling='avgpooling', im_size=(32, 32)):
        super(ConvNet, self).__init__()

        self.features, shape_feat = self._make_layers(channel, net_width, net_depth, net_norm, net_act, net_pooling,
                                                      im_size)
        num_feat = shape_feat[0] * shape_feat[1] * shape_feat[2]
        self.classifier1 = nn.Linear(num_feat, 256)
        self.classifier2 = nn.Linear(256, num_classes)
        self.flatten = paddle.nn.Flatten()

    def forward(self, x):
        h = self.features(x)
        
        _out = self.flatten(h)
        x = self.classifier1(_out)
        y = self.classifier2(x)
        return h, x, y

    def embed(self, x):
        _out = self.features(x)
        _out = self.flatten(_out)
        return _out

    def _get_activation(self, net_act):
        if net_act == 'sigmoid':
            return nn.Sigmoid()
        elif net_act == 'relu':
            return nn.ReLU()
        elif net_act == 'leakyrelu':
            return nn.LeakyReLU(negative_slope=0.01)
        elif net_act == 'swish':
            return Swish()
        else:
            exit('unknown activation function: %s' % net_act)

    def _get_pooling(self, net_pooling):
        if net_pooling == 'maxpooling':
            return nn.MaxPool2D(kernel_size=2, stride=2)
        elif net_pooling == 'avgpooling':
            return nn.AvgPool2D(kernel_size=2, stride=2)
        elif net_pooling == 'none':
            return None
        else:
            exit('unknown net_pooling: %s' % net_pooling)

    def _get_normlayer(self, net_norm, shape_feat):
        # shape_feat = (c*h*w)
        if net_norm == 'batchnorm':
            return nn.BatchNorm2D(shape_feat[0])
        elif net_norm == 'layernorm':
            return nn.LayerNorm(shape_feat)
        elif net_norm == 'instancenorm':
            return nn.GroupNorm(shape_feat[0], shape_feat[0])
        elif net_norm == 'groupnorm':
            return nn.GroupNorm(4, shape_feat[0])
        elif net_norm == 'none':
            return None
        else:
            exit('unknown net_norm: %s' % net_norm)

    def _make_layers(self, channel, net_width, net_depth, net_norm, net_act, net_pooling, im_size):
        layers = []
        in_channels = channel
        if im_size[0] == 28:
            im_size = (32, 32)
        shape_feat = [in_channels, im_size[0], im_size[1]]
        for d in range(net_depth):
            layers += [nn.Conv2D(in_channels=in_channels, out_channels=net_width, kernel_size=3, padding=3 if channel == 1 and d == 0 else 1)]
            shape_feat[0] = net_width
            if net_norm != 'none':
                layers += [self._get_normlayer(net_norm, shape_feat)]
            layers += [self._get_activation(net_act)]
            in_channels = net_width
            if net_pooling != 'none':
                layers += [self._get_pooling(net_pooling)]
                shape_feat[1] //= 2
                shape_feat[2] //= 2

        return nn.Sequential(*layers), shape_feat

# %%
def load_cifar10_data(datadir):

    transform_train = transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomCrop(32),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ])
    # data prep for test set
    transform_test = transforms.Compose([transforms.ToTensor()])

    cifar10_train_ds = CIFAR10(data_file=os.path.join(datadir, 'cifar-10-python.tar.gz'), mode='train', transform=transform_train)
    cifar10_test_ds = CIFAR10(data_file=os.path.join(datadir, 'cifar-10-python.tar.gz'), mode='test', transform=transform_test)

    Train_data = cifar10_train_ds.data
    Test_data = cifar10_test_ds.data
    X_train,y_train = np.array([x[0] for x in Train_data]), np.array([x[1] for x in Train_data])
    X_test,y_test = np.array([x[0] for x in Test_data]), np.array([x[1] for x in Test_data])
    
    return (cifar10_train_ds,cifar10_test_ds,X_train,y_train,X_test,y_test)

def load_mnist_data():

    transform_train = transforms.Compose([
        transforms.ToTensor(),
        transforms.RandomCrop(28),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ])
    # data prep for test set
    transform_test = transforms.Compose([transforms.ToTensor()])

    mnist_train_ds = MNIST(mode='train', transform=transform_train)
    mnist_test_ds = MNIST(mode='test', transform=transform_test)

    X_train,y_train = np.array([x[0] for x in mnist_train_ds]), np.array([x[1][0] for x in mnist_train_ds])
    X_test,y_test = np.array([x[0] for x in mnist_test_ds]), np.array([x[1][0] for x in mnist_test_ds])
    
    return (mnist_train_ds,mnist_test_ds,X_train,y_train,X_test,y_test)

def load_cifar100_data(datadir):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor()
    ])
    # data prep for test set
    transform_test = transforms.Compose([transforms.ToTensor()])

    cifar100_train_ds = CIFAR100(data_file=os.path.join(datadir, 'cifar-100-python.tar.gz'), mode='train', transform=transform_train)
    cifar100_test_ds = CIFAR100(data_file=os.path.join(datadir, 'cifar-100-python.tar.gz'), mode='test', transform=transform_test)

    Train_data = cifar100_train_ds.data
    Test_data = cifar100_test_ds.data

    X_train,y_train = np.array([x[0] for x in Train_data]), np.array([x[1] for x in Train_data])
    X_test,y_test = np.array([x[0] for x in Test_data]), np.array([x[1] for x in Test_data])

    return (cifar100_train_ds,cifar100_test_ds,X_train,y_train,X_test,y_test)

def record_net_data_stats(y_train, net_dataidx_map, logdir):

    net_cls_counts = {}

    for net_i, dataidx in net_dataidx_map.items():
        unq, unq_cnt = np.unique(y_train[dataidx], return_counts=True)
        tmp = {unq[i]: unq_cnt[i] for i in range(len(unq))}
        net_cls_counts[net_i] = tmp

    logger.info('Data statistics: %s' % str(net_cls_counts))

    return net_cls_counts
def partition_data(dataset, datadir, logdir, partition, n_parties, beta=0.4):
    if dataset == 'cifar10':
        _,_,X_train,y_train,X_test,y_test = load_cifar10_data(datadir)
        class_total_num = 10
    elif dataset == 'cifar100':
        _,_,X_train,y_train,X_test,y_test = load_cifar100_data(datadir)
        class_total_num = 100
    elif dataset == 'mnist':
        _,_,X_train,y_train,X_test,y_test = load_mnist_data()
        class_total_num = 10

    n_train = y_train.shape[0]

    if partition == "homo":
        idxs = np.random.permutation(n_train)
        batch_idxs = np.array_split(idxs, n_parties)
        net_dataidx_map = {i: batch_idxs[i] for i in range(n_parties)}

    elif partition == "noniid-labeldir":
        min_size = 0
        min_require_size = 10
        N = len(y_train)
        #np.random.seed(2020)
        net_dataidx_map = {}

        while min_size < min_require_size:
            idx_batch = [[] for _ in range(n_parties)]
            for k in range(class_total_num):
                idx_k = np.where(y_train == k)[0]
                np.random.shuffle(idx_k)
                proportions = np.random.dirichlet(np.repeat(beta, n_parties))
                # logger.info("proportions1: ", proportions)
                # logger.info("sum pro1:", np.sum(proportions))
                ## Balance
                proportions = np.array([p * (len(idx_j) < N / n_parties) for p, idx_j in zip(proportions, idx_batch)])
                # logger.info("proportions2: ", proportions)
                proportions = proportions / proportions.sum()
                # logger.info("proportions3: ", proportions)
                proportions = (np.cumsum(proportions) * len(idx_k)).astype(int)[:-1]
                # logger.info("proportions4: ", proportions)
                idx_batch = [idx_j + idx.tolist() for idx_j, idx in zip(idx_batch, np.split(idx_k, proportions))]
                min_size = min([len(idx_j) for idx_j in idx_batch])
                # if K == 2 and n_parties <= 10:
                #     if np.min(proportions) < 200:
                #         min_size = 0
                #         break
        for j in range(n_parties):
            np.random.shuffle(idx_batch[j])
            net_dataidx_map[j] = idx_batch[j]

    traindata_cls_counts = record_net_data_stats(y_train, net_dataidx_map, logdir)
    net_dataidx_map_ = {i:[[] for j in range(class_total_num)] for i in range(n_parties)}
    for i in range(n_parties):
        for j in net_dataidx_map[i]:
            idx = y_train[j]
            net_dataidx_map_[i][idx].append(j)
    return (X_train, y_train, X_test, y_test, net_dataidx_map, net_dataidx_map_, traindata_cls_counts)

# %%
seed = 0
np.random.seed(seed)
beta=0.5
dataset = 'mnist'

if dataset == 'cifar100':
    data_path = '../data/data152750'
    real_client_num = 10
    vir_clients_num = 10
    class_num=100
    num_per_class=500
    ch = 3
elif dataset == 'cifar10':
    data_path = '../data/data152754'
    real_client_num = 10
    vir_clients_num = 10
    class_num=10
    num_per_class=5000
    ch = 3
elif dataset == 'mnist':
    data_path = ""
    real_client_num = 10
    vir_clients_num = 10
    class_num=10
    num_per_class=6000
    ch = 1

X_train, y_train, X_test, y_test, net_dataidx_map, net_dataidx_map_, traindata_cls_counts = partition_data(
    dataset, data_path, 'logdir_test', 'noniid-labeldir', real_client_num, beta=beta)
# Out:
# INFO:root:Data statistics: {0: {0: 602, 2: 796, 3: 948, 4: 477, 5: 120, 6: 546, 7: 191, 8: 143, 9: 1650}, 1: {0: 820, 1: 2411, 2: 2824}, 2: {0: 770, 1: 25, 2: 669, 3: 963, 4: 2734, 5: 28, 6: 7, 7: 16, 8: 602, 9: 663}, 3: {0: 237, 1: 923, 2: 396, 3: 273, 4: 609, 5: 240, 6: 468, 7: 150, 8: 2975}, 4: {0: 241, 1: 409, 2: 58, 3: 1175, 4: 425, 5: 64, 6: 88, 7: 55, 8: 100, 9: 670}, 5: {0: 103, 1: 356, 3: 10, 4: 474, 5: 29, 6: 2121, 7: 554, 8: 888, 9: 2934}, 6: {0: 1430, 1: 2487, 2: 58, 3: 266, 4: 650, 5: 551, 6: 128, 7: 2929}, 7: {0: 554, 1: 1, 2: 160, 3: 51, 5: 1511, 6: 2451, 7: 1609}, 8: {0: 234, 1: 100, 2: 867, 3: 1177, 4: 77, 5: 2396, 6: 92, 7: 646, 8: 1133}, 9: {0: 932, 1: 30, 2: 130, 3: 1268, 4: 396, 5: 482, 6: 17, 7: 115, 8: 10, 9: 32}}

# %%
# each class total num of data
su = [0 for _ in range(class_num)]
for x in traindata_cls_counts.values():
    for i in range(class_num):
        try:
            su[i]+=x[i]
        except:
            continue
su
# Out:
# [5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949]

# %%
# each client total data
cl = [0 for _ in range(real_client_num)]
for idx,client in net_dataidx_map.items():
    cl[idx]+=len(client)
cl
# Out:
# [5473, 6055, 6477, 6271, 3285, 7469, 8499, 6337, 6722, 3412]

# %%
dataloader_virtual_matrix = [[[] for j in range(real_client_num)] for i in range(vir_clients_num)]
dataloader_virtual_matrix_dl = [[] for i in range(vir_clients_num)]
# dataloader_virtual_matrix

# %%
level = int(num_per_class / vir_clients_num)
for virtual_th in range(vir_clients_num):
    current_level = [level for i in range(class_num)]
    for client_th in range(real_client_num):
        for i in range(class_num):
            temp = current_level[i]
            dataloader_virtual_matrix[virtual_th][client_th].extend(net_dataidx_map_[client_th][i][:current_level[i]])
            current_level[i] -= len(net_dataidx_map_[client_th][i][:current_level[i]])
            net_dataidx_map_[client_th][i][:temp] = []
            # debug
            # print("client:{0} class:{1} has {2}".format(client_th, i, len(net_dataidx_map_[client_th][i])))
# dataloader_virtual_matrix

# %%
net_dataidx_map_
# all empty is right
# Out:
# {0: [[], [], [], [], [], [], [], [], [], []],
#  1: [[], [], [], [], [], [], [], [], [], []],
#  2: [[], [], [], [], [], [], [], [], [], []],
#  3: [[], [], [], [], [], [], [], [], [], []],
#  4: [[], [], [], [], [], [], [], [], [], []],
#  5: [[], [], [], [], [], [], [], [], [], []],
#  6: [[],
#   [9069,
#    13947,
#    49697,
#    15271,
#    24895,
#    59460,
#    14834,
#    16565,
#    46204,
#    10885,
#    55397,
#    11634,
#    46949,
#    33937,
#    36687,
#    4190,
#    747,
#    44158,
#    13106,
#    32710,
#    46842,
#    48949,
#    50150,
#    44677,
#    34749,
#    42806,
#    18116,
#    38847,
#    38454,
#    41536,
#    57272,
#    5630,
#    57160,
#    49488,
#    33279,
#    37741,
#    1942,
#    10318,
#    25473,
#    54946,
#    8087,
#    33091,
#    54269,
#    47535,
#    40007,
#    52205,
#    4900,
#    33998,
#    36457,
#    22931,
#    112,
#    4942,
#    9910,
#    56831,
#    40525,
#    40362,
#    19304,
#    33556,
#    28153,
#    16086,
#    49852,
#    30337,
#    34725,
#    21272,
#    30148,
#    8839,
#    52359,
#    56189,
#    23970,
#    57095,
#    10541,
#    17782,
#    26238,
#    36943,
#    11522,
#    57385,
#    23404,
#    37499,
#    50338,
#    58991,
#    45221,
#    48024,
#    24328,
#    16923,
#    15974,
#    47837,
#    4913,
#    1700,
#    19096,
#    53593,
#    39988,
#    28245,
#    4300,
#    17925,
#    23036,
#    35299,
#    510,
#    40744,
#    41744,
#    52143,
#    51539,
#    33684,
#    34033,
#    19091,
#    30731,
#    56734,
#    1293,
#    24306,
#    38582,
#    10134,
#    48229,
#    8402,
#    7910,
#    32447,
#    2762,
#    16483,
#    21288,
#    7671,
#    41894,
#    15255,
#    10325,
#    13260,
#    54005,
#    47869,
#    57749,
#    55080,
#    30564,
#    8106,
#    32741,
#    5840,
#    205,
#    31280,
#    25696,
#    18053,
#    20178,
#    25822,
#    6116,
#    48513,
#    8156,
#    41836,
#    56559,
#    39052,
#    2878,
#    37716,
#    35862,
#    55574,
#    18196,
#    57684,
#    12693,
#    9973,
#    55609,
#    50292,
#    32979,
#    47435,
#    32597,
#    4137,
#    10399,
#    9903,
#    6408,
#    34493,
#    6206,
#    6197,
#    43927,
#    19991,
#    24966,
#    36682,
#    2307,
#    29451,
#    15999,
#    10067,
#    40884,
#    17885,
#    23181,
#    33902,
#    44093,
#    21465,
#    36591,
#    42701,
#    4248,
#    8471,
#    29812,
#    52368,
#    46236,
#    24678,
#    59994,
#    50907,
#    6021,
#    15929,
#    7324,
#    44648,
#    17240,
#    16914,
#    33774,
#    10686,
#    36626,
#    46029,
#    4944,
#    44339,
#    56744,
#    12746,
#    16224,
#    22868,
#    27068,
#    4387,
#    5375,
#    58903,
#    13556,
#    43300,
#    52819,
#    1945,
#    33826,
#    56208,
#    4333,
#    30053,
#    17125,
#    42546,
#    46512,
#    12807,
#    15048,
#    28420,
#    5833,
#    17259,
#    53330,
#    8595,
#    56374,
#    42132,
#    19452,
#    11236,
#    8778,
#    30963,
#    12791,
#    21978,
#    41454,
#    31784,
#    34826,
#    52738,
#    51529,
#    43567,
#    24183,
#    1354,
#    22896,
#    52906,
#    23660,
#    13725,
#    24288,
#    59297,
#    21054,
#    45803,
#    20817,
#    35856,
#    40140,
#    42015,
#    2906,
#    5483,
#    39830,
#    51372,
#    12722,
#    8351,
#    12141,
#    38449,
#    15224,
#    56955,
#    12987,
#    53805,
#    24135,
#    14615,
#    38340,
#    8919,
#    57714,
#    17058,
#    21301,
#    39716,
#    15632,
#    32378,
#    50103,
#    8051,
#    45254,
#    36297,
#    6052,
#    57069,
#    38305,
#    55846,
#    17704,
#    56689,
#    20045,
#    36908,
#    39560,
#    27276,
#    35942,
#    56261,
#    46006,
#    23003,
#    15428,
#    56870,
#    58561,
#    48266,
#    19339,
#    5507,
#    3080,
#    30104,
#    55067,
#    919,
#    43704,
#    10886,
#    27329,
#    25524,
#    16259,
#    47773,
#    13985,
#    41567,
#    10915,
#    29233,
#    39818,
#    51149,
#    16241,
#    54485,
#    13160,
#    56683,
#    11156,
#    38974,
#    19753,
#    36110,
#    6135,
#    42765,
#    13227,
#    19552,
#    18761,
#    57644,
#    8679,
#    9136,
#    2843,
#    54165,
#    6511,
#    25436,
#    6229,
#    7941,
#    21847,
#    48793,
#    29239,
#    55236,
#    52616,
#    14812,
#    55710,
#    35313,
#    29666,
#    25264,
#    53891,
#    56882,
#    9106,
#    7084,
#    31286,
#    12215,
#    7533,
#    30567,
#    43349,
#    57268,
#    49600,
#    21460,
#    14503,
#    21682,
#    2086,
#    52244,
#    6665,
#    48189,
#    58586,
#    9628,
#    18163,
#    16944,
#    41897,
#    47004,
#    47935,
#    13501,
#    41879,
#    20083,
#    53310,
#    43905,
#    25687,
#    54094,
#    40551,
#    27792,
#    18256,
#    48645,
#    39646,
#    29609,
#    40802,
#    10852,
#    49068,
#    49087,
#    38697,
#    14309,
#    15898,
#    38125,
#    30100,
#    50631,
#    28484,
#    1597,
#    57339,
#    27256,
#    45001,
#    31701,
#    16262,
#    40423,
#    48461,
#    30742,
#    11943,
#    30238,
#    59713,
#    53080,
#    29260,
#    6617,
#    59114,
#    19652,
#    51195,
#    48931,
#    6104,
#    54974,
#    39160,
#    42875,
#    36422,
#    1936,
#    10365,
#    27388,
#    55175,
#    20772,
#    32879,
#    14900,
#    29544,
#    11069,
#    10220,
#    54239,
#    13590,
#    42307,
#    31980,
#    16656,
#    40045,
#    39033,
#    9256,
#    54340,
#    58913,
#    8451,
#    59354,
#    24848,
#    56912,
#    24707,
#    5963,
#    6003,
#    31174,
#    23030,
#    30218,
#    39757,
#    33725,
#    58689,
#    43535,
#    1838,
#    45816,
#    54059,
#    43664,
#    24619,
#    26867,
#    56696,
#    1859,
#    30292,
#    56865,
#    57454,
#    1458,
#    78,
#    28834,
#    4569,
#    10892,
#    24466,
#    43429,
#    40148,
#    37923,
#    16211,
#    23254,
#    15026,
#    18853,
#    26910,
#    57571,
#    17607,
#    34206,
#    18174,
#    17942,
#    19167,
#    41816,
#    54023,
#    53707,
#    50979,
#    7393,
#    30996,
#    29215,
#    53178,
#    30607,
#    54544,
#    17418,
#    4623,
#    18524,
#    30493,
#    6985,
#    19622,
#    55140,
#    26152,
#    16876,
#    19136,
#    3755,
#    5915,
#    2563,
#    24535,
#    50731,
#    5439,
#    6709,
#    25767,
#    8464,
#    10156,
#    47234,
#    21535,
#    36814,
#    33332,
#    27528,
#    5527,
#    32890,
#    54434,
#    30171,
#    43214,
#    34261,
#    57440,
#    4507,
#    47224,
#    49610,
#    54417,
#    32814,
#    45076,
#    50830,
#    40373,
#    39819,
#    14948,
#    134,
#    22700,
#    57830,
#    52084,
#    29810,
#    38561,
#    5176,
#    54864,
#    1425,
#    20302,
#    2794,
#    20212,
#    40973,
#    20018,
#    13697,
#    55784,
#    19749,
#    42494,
#    38016,
#    22937,
#    18942,
#    59697,
#    40568,
#    16475,
#    31771,
#    3811,
#    15959,
#    27885,
#    7912,
#    44724,
#    55819,
#    58995,
#    29902,
#    47542,
#    33326,
#    11107,
#    54708,
#    6609,
#    44524,
#    1331,
#    33176,
#    15507,
#    36164,
#    38928,
#    33861,
#    3954,
#    56221,
#    9796,
#    16855,
#    39057,
#    52731,
#    39270,
#    17943,
#    31642,
#    49362,
#    8222,
#    18421,
#    9960,
#    54816,
#    57362,
#    13453,
#    53610,
#    37761,
#    14651,
#    48481,
#    53103,
#    38965,
#    29041,
#    8989,
#    2083,
#    59616,
#    30427,
#    36778,
#    18568,
#    42424],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []],
#  7: [[], [14936], [], [], [], [], [], [], [], []],
#  8: [[],
#   [41282,
#    22412,
#    54428,
#    23889,
#    56737,
#    20361,
#    53041,
#    43389,
#    3375,
#    23921,
#    7440,
#    28134,
#    45994,
#    11279,
#    17637,
#    8418,
#    51110,
#    12128,
#    3729,
#    21173,
#    50465,
#    42673,
#    29807,
#    21357,
#    51187,
#    20611,
#    40908,
#    38081,
#    1717,
#    43296,
#    22727,
#    57906,
#    39367,
#    15809,
#    47928,
#    41750,
#    14427,
#    35328,
#    37563,
#    31578,
#    16983,
#    5957,
#    22345,
#    46913,
#    38570,
#    10285,
#    32530,
#    12356,
#    20459,
#    3394,
#    17423,
#    30145,
#    48261,
#    51836,
#    58985,
#    43025,
#    366,
#    13542,
#    31386,
#    50056,
#    46601,
#    18072,
#    58580,
#    52136,
#    39554,
#    15099,
#    37023,
#    32179,
#    59156,
#    19297,
#    19158,
#    47993,
#    52268,
#    2619,
#    11537,
#    49118,
#    18806,
#    4441,
#    34595,
#    4654,
#    39444,
#    6142,
#    35897,
#    8704,
#    44680,
#    13514,
#    23892,
#    47770,
#    35289,
#    2045,
#    34074,
#    56192,
#    34359,
#    22545,
#    55634,
#    8529,
#    48361,
#    45723,
#    55567,
#    67],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [40603,
#    50255,
#    44774,
#    26162,
#    17373,
#    52124,
#    43763,
#    56932,
#    59360,
#    19199,
#    19817,
#    50742,
#    13571,
#    21123,
#    14022,
#    37394,
#    56555,
#    34415,
#    52528,
#    38133,
#    56160,
#    25095,
#    12081,
#    3343,
#    59115,
#    46042,
#    38186,
#    42320,
#    59592,
#    349,
#    55693,
#    14379,
#    30801,
#    10408,
#    26489,
#    54789,
#    46957,
#    56924,
#    43926,
#    40742,
#    15792,
#    51126,
#    12453,
#    5723,
#    44443,
#    29633,
#    42528,
#    18951,
#    27357,
#    21700,
#    4995,
#    10841,
#    10309,
#    47536,
#    12428,
#    31542,
#    17795,
#    44943,
#    384,
#    46278,
#    35101,
#    32920,
#    6140,
#    11564,
#    29382,
#    1072,
#    34609,
#    12896,
#    56806,
#    48135,
#    50438,
#    19592,
#    79,
#    3250,
#    36767,
#    20030,
#    31300,
#    27532,
#    18173,
#    4164,
#    34772,
#    41844,
#    32662,
#    25816,
#    25339,
#    49277,
#    8931,
#    54278,
#    33017,
#    8437,
#    23443,
#    50227,
#    44059,
#    12031,
#    19658,
#    26049,
#    33957,
#    38034,
#    25868,
#    1636,
#    39649,
#    37500,
#    46724,
#    49554,
#    35860,
#    14598,
#    43089,
#    9214,
#    45901,
#    21387,
#    17424,
#    58128,
#    10640,
#    56064,
#    8142,
#    5768,
#    44640,
#    8044,
#    54439,
#    6134,
#    31391,
#    25727,
#    45804,
#    47852,
#    39439,
#    12185,
#    18557,
#    28730,
#    34576,
#    54890,
#    56816,
#    36763,
#    33348,
#    42134,
#    57581,
#    35625,
#    52137,
#    11854,
#    31690,
#    31850,
#    13978,
#    16437,
#    3899,
#    2344,
#    28443,
#    13746,
#    50664,
#    44257,
#    48125,
#    35648],
#   [],
#   []],
#  9: [[],
#   [14701,
#    50094,
#    40069,
#    24405,
#    12706,
#    10581,
#    52431,
#    37926,
#    2725,
#    38897,
#    3714,
#    52715,
#    28250,
#    1085,
#    24710,
#    41205,
#    50498,
#    17232,
#    47969,
#    47259,
#    25129,
#    30920,
#    28794,
#    46173,
#    36469,
#    14929,
#    59488,
#    3295,
#    43948,
#    533],
#   [],
#   [23344,
#    2179,
#    57166,
#    47195,
#    7765,
#    57679,
#    30717,
#    56488,
#    21359,
#    11756,
#    15346,
#    9602,
#    10402,
#    52994,
#    14903,
#    13250,
#    54782,
#    28759,
#    10099,
#    5252,
#    3258,
#    13202,
#    33772,
#    48431,
#    49602,
#    42534,
#    17127,
#    20121,
#    27060,
#    9977,
#    3192,
#    51947,
#    57492,
#    25802,
#    39706,
#    33507,
#    12392,
#    19465,
#    16764,
#    808,
#    57207,
#    52134,
#    14863,
#    27095,
#    29146,
#    37903,
#    4543,
#    43204,
#    22770,
#    1883,
#    46279,
#    51768,
#    12330,
#    54460,
#    19834,
#    37540,
#    59978,
#    47217,
#    12214,
#    23663,
#    7600,
#    18397,
#    9401,
#    35703,
#    13706,
#    49307,
#    47618,
#    59715,
#    25915,
#    8957,
#    50500,
#    26130,
#    33795,
#    40480,
#    31636,
#    58966,
#    12329,
#    57172,
#    1119,
#    45266,
#    20869,
#    58097,
#    11929,
#    42041,
#    38445,
#    35434,
#    23986,
#    6825,
#    3178,
#    55866,
#    44567,
#    45480,
#    55845,
#    53514,
#    34175,
#    57932,
#    41071,
#    58079,
#    14303,
#    48291,
#    54953,
#    16626,
#    37912,
#    6561,
#    25861,
#    33854,
#    49286,
#    50529,
#    19579,
#    5092,
#    49893,
#    21795,
#    23412,
#    7584,
#    7263,
#    46911,
#    51918,
#    57227,
#    22488,
#    27726,
#    26866,
#    59275,
#    59151,
#    34556,
#    17491,
#    43557,
#    57766,
#    54559,
#    18030,
#    10031,
#    6123],
#   [],
#   [],
#   [],
#   [34118,
#    20422,
#    17946,
#    35372,
#    9467,
#    20354,
#    27971,
#    55059,
#    48190,
#    15422,
#    37193,
#    58094,
#    5986,
#    599,
#    21885,
#    37147,
#    18534,
#    38437,
#    43555,
#    25439,
#    56769,
#    3769,
#    39877,
#    4020,
#    5253,
#    46153,
#    47262,
#    54937,
#    9470,
#    1302,
#    43340,
#    651,
#    24572,
#    44572,
#    20229,
#    4317,
#    14643,
#    18753,
#    36197,
#    34506,
#    36395,
#    46851,
#    37657,
#    17762,
#    20406,
#    25581,
#    4326,
#    36003,
#    5584,
#    10181,
#    57702,
#    7769,
#    21217,
#    53102,
#    26528,
#    5437,
#    20707,
#    39989,
#    40387,
#    37818,
#    14386,
#    50100,
#    12233,
#    52779,
#    22300,
#    13174,
#    37288,
#    6986,
#    17649,
#    28558,
#    22007,
#    44911,
#    52490,
#    19534,
#    2187,
#    10727,
#    28632,
#    32844,
#    28535,
#    24568,
#    20996,
#    7085,
#    35476,
#    23540,
#    38972,
#    54317,
#    683,
#    53836,
#    14095,
#    33717,
#    15243,
#    56076,
#    51974,
#    16162,
#    53074,
#    16271,
#    48992,
#    36012,
#    9382,
#    25543,
#    11407,
#    35130,
#    4363,
#    58826,
#    3915,
#    55374,
#    2754,
#    41088,
#    40214,
#    19184,
#    23978,
#    27722,
#    9433,
#    20310,
#    32589],
#   [],
#   []]}

# %%
def get_dataloader(dataset, datadir, train_bs, test_bs, dataidxs=None, is_test=False):
    if dataset in ('mnist', 'femnist', 'fmnist', 'cifar10', 'svhn', 'generated', 'covtype', 'a9a', 'rcv1', 'SUSY','cifar100'):
        if dataset == 'cifar10':
            train_ds,_,_,_,_,_ = load_cifar10_data(datadir)
            if dataidxs is not None:
                train_ds = [train_ds[i] for i in dataidxs]
            if is_test:
                _,test_ds,_,_,_,_ = load_cifar10_data(datadir)
        elif dataset == 'cifar100':
            train_ds,_,_,_,_,_ = load_cifar100_data(datadir)
            if dataidxs is not None:
                train_ds = [train_ds[i] for i in dataidxs]
            if is_test:
                _,test_ds,_,_,_,_ = load_cifar100_data(datadir)
        elif dataset == 'mnist':
            train_ds,_,_,_,_,_ = load_mnist_data()
            if dataidxs is not None:
                train_ds = [train_ds[i] for i in dataidxs]
            if is_test:
                _,test_ds,_,_,_,_ = load_mnist_data()
        else:
            train_ds, test_ds = None, None

        train_dl = DataLoader(dataset=train_ds, batch_size=train_bs, shuffle=True, drop_last=False)
        if is_test:
            test_dl = DataLoader(dataset=test_ds, batch_size=test_bs, shuffle=False, drop_last=False)
            return train_dl,test_dl
        else:
            return train_dl

# %%
def compute_accuracy(model, dataloader):
    model.eval()
    accuracies = []
    losses = []
    for batch_id, (x_data,y_data) in enumerate(dataloader()):

        y_data = paddle.to_tensor(y_data)
        if dataset != 'mnist':
            y_data = paddle.unsqueeze(y_data, 1)

        _,_,logits = model(x_data)
        loss = F.cross_entropy(logits, y_data)
        acc = paddle.metric.accuracy(logits, y_data)
        accuracies.append(acc.numpy())
        losses.append(loss.numpy())

    avg_acc, avg_loss = np.mean(accuracies), np.mean(losses)

    return avg_acc

# %%
sum_ = 0
for net in traindata_cls_counts.values():
    try:
        sum_ += net[0]
    except:
        continue
print(f'each class total num:[{sum_}], set virtual_client_num:[10], per:[{int(sum_/10)}]')
# Out:
# each class total num:[5923], set virtual_client_num:[10], per:[592]

# %%
for virtual_client_dl_idx in range(len(dataloader_virtual_matrix)):
    for real_client_dl_idx in dataloader_virtual_matrix[virtual_client_dl_idx]:
        if real_client_dl_idx == []:
            dataloader_virtual_matrix_dl[virtual_client_dl_idx].append([])
            continue
        train_dl_local= get_dataloader(dataset, data_path, 64, 32, real_client_dl_idx, is_test=False)
        dataloader_virtual_matrix_dl[virtual_client_dl_idx].append(train_dl_local)

# %%
dataloader_virtual_matrix_dl
# Out:
# [[<paddle.fluid.reader.DataLoader at 0x7fbc95315ad0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb00a96d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9555d890>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc93ff1fd0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9499c290>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9544c0d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcc82e1fd0>,
#   [],
#   [],
#   []],
#  [<paddle.fluid.reader.DataLoader at 0x7fbc952e3690>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc952f1210>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc952bae90>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc951a0210>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc93e554d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc94c15ad0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcba0d4290>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc94c1f1d0>,
#   [],
#   []],
#  [<paddle.fluid.reader.DataLoader at 0x7fbcba04ddd0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc95190d10>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc94fad550>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcba020090>,
#   [],
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9ff3050>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc941f7e90>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc949a2d50>,
#   [],
#   []],
#  [[],
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9ff3f50>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc94c2c2d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc94fb35d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc94de9910>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcba1e5790>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcba1e5f10>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcba05e550>,
#   [],
#   []],
#  [[],
#   <paddle.fluid.reader.DataLoader at 0x7fbcba1e5050>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9de6650>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9de6790>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcba1dc7d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc95279410>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc95221590>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9501bb50>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9e120d0>,
#   []],
#  [[],
#   <paddle.fluid.reader.DataLoader at 0x7fbc95360910>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9502b490>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9414b150>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9d72fd0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9ca3950>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9d3af10>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9cabe10>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc948be790>,
#   []],
#  [[],
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9ca31d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9c71cd0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9e18190>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9bfacd0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9bc9cd0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9529f250>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc9529f510>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9addd10>,
#   []],
#  [[],
#   [],
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9c2a790>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc950ef5d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9d24090>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9b84a50>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9c14cd0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9aeb210>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9b81950>,
#   []],
#  [[],
#   [],
#   [],
#   [],
#   [],
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9b99190>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9a5be10>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9c22850>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcba1fed50>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9f05350>],
#  [[],
#   [],
#   [],
#   [],
#   [],
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9964810>,
#   <paddle.fluid.reader.DataLoader at 0x7fbc942b9a50>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb9a2f710>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb995e7d0>,
#   <paddle.fluid.reader.DataLoader at 0x7fbcb99bfcd0>]]

# %%
import time

args_optimizer = 'sgd'
lr = 0.01
reg = 5e-4
acc_list = []
rounds = 20
epochs = 10

net = ConvNet(channel=ch, num_classes=class_num, net_width=128, net_depth=3, net_act='relu', net_norm='instancenorm', net_pooling='avgpooling', im_size=(32, 32))

_,test_dl = get_dataloader(dataset, data_path, 64, 32, is_test=True)


if args_optimizer == 'adam':
    optimizer = optim.Adam(parameters=net.parameters(), learning_rate=lr, weight_decay=reg)
else:
    optimizer = optim.SGD(parameters=net.parameters(), learning_rate=lr, weight_decay=reg)

# %%
for rd in range(rounds):
    rd_time = time.time()
    virtual_id = 0
    for virtual_client_dl in dataloader_virtual_matrix_dl:
        for epoch in range(epochs):
            ep_time = time.time()
            for train_dl_local in virtual_client_dl:
                if train_dl_local == []:
                    continue
                for batch_idx, (x, target) in enumerate(train_dl_local()):
                    _, _, out = net(x)
                    loss = F.cross_entropy(out, target)

                    loss.backward()
                    optimizer.step()
                    optimizer.clear_grad()
            print("round::{0}, virtual_client::{1}, epoch::{2}, loss::{3}, elps_time::{4}.".format(rd,virtual_id,epoch,loss.item(),time.time()-ep_time))
        virtual_id += 1
    acc = compute_accuracy(net, test_dl)
    acc_list.append(acc)
    print("round::{0} finished, test_acc::{1}, elpsed time::{2}".format(rd,acc,time.time()-rd_time))
# Out:
# round::0, virtual_client::0, epoch::0, loss::0.005617660935968161, elps_time::1.015599250793457.
# round::0, virtual_client::0, epoch::1, loss::0.019943634048104286, elps_time::0.9458293914794922.
# round::0, virtual_client::0, epoch::2, loss::0.006331684999167919, elps_time::0.8664422035217285.
# round::0, virtual_client::0, epoch::3, loss::0.030031226575374603, elps_time::0.8944525718688965.
# round::0, virtual_client::0, epoch::4, loss::0.020967215299606323, elps_time::0.8598661422729492.
# round::0, virtual_client::0, epoch::5, loss::0.015225464478135109, elps_time::0.8699727058410645.
# round::0, virtual_client::0, epoch::6, loss::0.05643472820520401, elps_time::0.8712093830108643.
# round::0, virtual_client::0, epoch::7, loss::0.04190671443939209, elps_time::0.8693714141845703.
# round::0, virtual_client::0, epoch::8, loss::0.05591640621423721, elps_time::0.8530957698822021.
# round::0, virtual_client::0, epoch::9, loss::0.026932865381240845, elps_time::0.8966121673583984.
# round::0, virtual_client::1, epoch::0, loss::0.024777144193649292, elps_time::0.8751621246337891.
# round::0, virtual_client::1, epoch::1, loss::0.010653319768607616, elps_time::0.9259731769561768.
# round::0, virtual_client::1, epoch::2, loss::0.028981436043977737, elps_time::0.9309995174407959.
# round::0, virtual_client::1, epoch::3, loss::0.018026050180196762, elps_time::0.9323406219482422.
# round::0, virtual_client::1, epoch::4, loss::0.02518419921398163, elps_time::0.8983392715454102.
# round::0, virtual_client::1, epoch::5, loss::0.01625506393611431, elps_time::0.9061036109924316.
# round::0, virtual_client::1, epoch::6, loss::0.0040387739427387714, elps_time::0.8935132026672363.
# round::0, virtual_client::1, epoch::7, loss::0.023102065548300743, elps_time::0.862847089767456.
# round::0, virtual_client::1, epoch::8, loss::0.020737791433930397, elps_time::0.9532086849212646.
# round::0, virtual_client::1, epoch::9, loss::0.02108648419380188, elps_time::0.8885571956634521.
# round::0, virtual_client::2, epoch::0, loss::0.0017386286053806543, elps_time::0.8844013214111328.
# round::0, virtual_client::2, epoch::1, loss::0.0034999216441065073, elps_time::0.8765697479248047.
# round::0, virtual_client::2, epoch::2, loss::0.006002762820571661, elps_time::0.9939048290252686.
# round::0, virtual_client::2, epoch::3, loss::0.0036545079201459885, elps_time::0.9938454627990723.
# round::0, virtual_client::2, epoch::4, loss::0.013498133979737759, elps_time::1.0447821617126465.
# round::0, virtual_client::2, epoch::5, loss::0.04455307871103287, elps_time::1.1398050785064697.
# round::0, virtual_client::2, epoch::6, loss::0.027951406314969063, elps_time::1.1520769596099854.
# round::0, virtual_client::2, epoch::7, loss::0.010593178682029247, elps_time::1.1218352317810059.
# round::0, virtual_client::2, epoch::8, loss::0.029609065502882004, elps_time::1.0737619400024414.
# round::0, virtual_client::2, epoch::9, loss::0.007191389799118042, elps_time::1.065298080444336.
# round::0, virtual_client::3, epoch::0, loss::0.016293058171868324, elps_time::1.056062936782837.
# round::0, virtual_client::3, epoch::1, loss::0.004415611736476421, elps_time::1.061492919921875.
# round::0, virtual_client::3, epoch::2, loss::0.002085246378555894, elps_time::1.0819652080535889.
# round::0, virtual_client::3, epoch::3, loss::0.00777062401175499, elps_time::1.089277744293213.
# round::0, virtual_client::3, epoch::4, loss::0.004350542556494474, elps_time::1.1214466094970703.
# round::0, virtual_client::3, epoch::5, loss::0.15927979350090027, elps_time::1.1030380725860596.
# round::0, virtual_client::3, epoch::6, loss::0.0028279118705540895, elps_time::1.1168529987335205.
# round::0, virtual_client::3, epoch::7, loss::0.002141128061339259, elps_time::1.0210113525390625.
# round::0, virtual_client::3, epoch::8, loss::0.004256215877830982, elps_time::0.9417848587036133.
# round::0, virtual_client::3, epoch::9, loss::0.014395717531442642, elps_time::0.9670772552490234.
# round::0, virtual_client::4, epoch::0, loss::0.001171317184343934, elps_time::0.9450702667236328.
# round::0, virtual_client::4, epoch::1, loss::0.0012195430463179946, elps_time::0.9231109619140625.
# round::0, virtual_client::4, epoch::2, loss::0.0016724788583815098, elps_time::0.9206514358520508.
# round::0, virtual_client::4, epoch::3, loss::0.004032706841826439, elps_time::0.9147834777832031.
# round::0, virtual_client::4, epoch::4, loss::0.12340478599071503, elps_time::0.8937156200408936.
# round::0, virtual_client::4, epoch::5, loss::0.001417543739080429, elps_time::0.9191021919250488.
# round::0, virtual_client::4, epoch::6, loss::0.03761163726449013, elps_time::0.8959197998046875.
# round::0, virtual_client::4, epoch::7, loss::0.002351414179429412, elps_time::0.8977391719818115.
# round::0, virtual_client::4, epoch::8, loss::0.0058340211398899555, elps_time::0.9128029346466064.
# round::0, virtual_client::4, epoch::9, loss::0.00305624189786613, elps_time::0.8702991008758545.
# round::0, virtual_client::5, epoch::0, loss::0.025149092078208923, elps_time::0.9228801727294922.
# round::0, virtual_client::5, epoch::1, loss::0.01374926045536995, elps_time::0.9138965606689453.
# round::0, virtual_client::5, epoch::2, loss::0.012927384115755558, elps_time::0.9576864242553711.
# round::0, virtual_client::5, epoch::3, loss::0.01890750043094158, elps_time::0.963249683380127.
# round::0, virtual_client::5, epoch::4, loss::0.00917860958725214, elps_time::0.9723458290100098.
# round::0, virtual_client::5, epoch::5, loss::0.018078045919537544, elps_time::0.9617316722869873.
# round::0, virtual_client::5, epoch::6, loss::0.004055238328874111, elps_time::0.9486691951751709.
# round::0, virtual_client::5, epoch::7, loss::0.03362768143415451, elps_time::0.9038257598876953.
# round::0, virtual_client::5, epoch::8, loss::0.004438983742147684, elps_time::0.9594168663024902.
# round::0, virtual_client::5, epoch::9, loss::0.08620558679103851, elps_time::0.9154644012451172.
# round::0, virtual_client::6, epoch::0, loss::0.21508963406085968, elps_time::0.8860139846801758.
# round::0, virtual_client::6, epoch::1, loss::0.14638477563858032, elps_time::0.9251084327697754.
# round::0, virtual_client::6, epoch::2, loss::0.16875557601451874, elps_time::0.8920533657073975.
# round::0, virtual_client::6, epoch::3, loss::0.07023463398218155, elps_time::0.9506945610046387.
# round::0, virtual_client::6, epoch::4, loss::0.08977828174829483, elps_time::0.9354438781738281.
# round::0, virtual_client::6, epoch::5, loss::0.17531254887580872, elps_time::0.9404010772705078.
# round::0, virtual_client::6, epoch::6, loss::0.13204973936080933, elps_time::0.9943149089813232.
# round::0, virtual_client::6, epoch::7, loss::0.16528773307800293, elps_time::0.9973950386047363.
# round::0, virtual_client::6, epoch::8, loss::0.1486760675907135, elps_time::0.9386537075042725.
# round::0, virtual_client::6, epoch::9, loss::0.04881741851568222, elps_time::0.9220197200775146.
# round::0, virtual_client::7, epoch::0, loss::0.19841083884239197, elps_time::0.8957297801971436.
# round::0, virtual_client::7, epoch::1, loss::0.13647358119487762, elps_time::0.8766214847564697.
# round::0, virtual_client::7, epoch::2, loss::0.06643682718276978, elps_time::0.8708517551422119.
# round::0, virtual_client::7, epoch::3, loss::0.11572758853435516, elps_time::0.8938586711883545.
# round::0, virtual_client::7, epoch::4, loss::0.07742965966463089, elps_time::0.8902642726898193.
# round::0, virtual_client::7, epoch::5, loss::0.08240865170955658, elps_time::0.8898947238922119.
# round::0, virtual_client::7, epoch::6, loss::0.09926444292068481, elps_time::0.9237117767333984.
# round::0, virtual_client::7, epoch::7, loss::0.08960667997598648, elps_time::0.8922631740570068.
# round::0, virtual_client::7, epoch::8, loss::0.06374486535787582, elps_time::0.8815090656280518.
# round::0, virtual_client::7, epoch::9, loss::0.05374513566493988, elps_time::0.8577744960784912.
# round::0, virtual_client::8, epoch::0, loss::0.10759437084197998, elps_time::0.8761036396026611.
# round::0, virtual_client::8, epoch::1, loss::0.05496196448802948, elps_time::0.8569540977478027.
# round::0, virtual_client::8, epoch::2, loss::0.059503551572561264, elps_time::0.8586289882659912.
# round::0, virtual_client::8, epoch::3, loss::0.1128581166267395, elps_time::0.8892273902893066.
# round::0, virtual_client::8, epoch::4, loss::0.030077679082751274, elps_time::0.8732986450195312.
# round::0, virtual_client::8, epoch::5, loss::0.020171359181404114, elps_time::0.8926713466644287.
# round::0, virtual_client::8, epoch::6, loss::0.017598142847418785, elps_time::0.8616197109222412.
# round::0, virtual_client::8, epoch::7, loss::0.04796742647886276, elps_time::0.8694579601287842.
# round::0, virtual_client::8, epoch::8, loss::0.03556961566209793, elps_time::0.8424091339111328.
# round::0, virtual_client::8, epoch::9, loss::0.02617376297712326, elps_time::0.8580408096313477.
# round::0, virtual_client::9, epoch::0, loss::0.014611735939979553, elps_time::0.7675809860229492.
# round::0, virtual_client::9, epoch::1, loss::0.1130945011973381, elps_time::0.8220953941345215.
# round::0, virtual_client::9, epoch::2, loss::0.035114437341690063, elps_time::0.9073562622070312.
# round::0, virtual_client::9, epoch::3, loss::4.625213477993384e-05, elps_time::1.010448694229126.
# round::0, virtual_client::9, epoch::4, loss::0.0001003691868390888, elps_time::0.9049234390258789.
# round::0, virtual_client::9, epoch::5, loss::0.4654771089553833, elps_time::0.8738758563995361.
# round::0, virtual_client::9, epoch::6, loss::0.001291037304326892, elps_time::0.9122130870819092.
# round::0, virtual_client::9, epoch::7, loss::0.013125448487699032, elps_time::0.8857114315032959.
# round::0, virtual_client::9, epoch::8, loss::0.00042489083716645837, elps_time::0.8788943290710449.
# round::0, virtual_client::9, epoch::9, loss::0.0001436368766007945, elps_time::0.8883774280548096.
# round::0 finished, test_acc::0.9466853141784668, elpsed time::100.53473663330078
# round::1, virtual_client::0, epoch::0, loss::0.008765557780861855, elps_time::0.9764628410339355.
# round::1, virtual_client::0, epoch::1, loss::0.006755199283361435, elps_time::0.9374933242797852.
# round::1, virtual_client::0, epoch::2, loss::0.015073596499860287, elps_time::0.8894457817077637.
# round::1, virtual_client::0, epoch::3, loss::0.023801589384675026, elps_time::0.8954892158508301.
# round::1, virtual_client::0, epoch::4, loss::0.017072640359401703, elps_time::0.8815360069274902.
# round::1, virtual_client::0, epoch::5, loss::0.015412462875247002, elps_time::0.8717079162597656.
# round::1, virtual_client::0, epoch::6, loss::0.011224714107811451, elps_time::0.8862628936767578.
# round::1, virtual_client::0, epoch::7, loss::0.024645689874887466, elps_time::0.8723998069763184.
# round::1, virtual_client::0, epoch::8, loss::0.019885201007127762, elps_time::0.908287525177002.
# round::1, virtual_client::0, epoch::9, loss::0.022593669593334198, elps_time::0.917461633682251.
# round::1, virtual_client::1, epoch::0, loss::0.0067852637730538845, elps_time::0.9159553050994873.
# round::1, virtual_client::1, epoch::1, loss::0.0034568302799016237, elps_time::0.9314146041870117.
# round::1, virtual_client::1, epoch::2, loss::0.004456591326743364, elps_time::0.9595401287078857.
# round::1, virtual_client::1, epoch::3, loss::0.011642618104815483, elps_time::0.9723834991455078.
# round::1, virtual_client::1, epoch::4, loss::0.004044880159199238, elps_time::0.9628050327301025.
# round::1, virtual_client::1, epoch::5, loss::0.003123838920146227, elps_time::0.9311316013336182.
# round::1, virtual_client::1, epoch::6, loss::0.007291726768016815, elps_time::0.9096744060516357.
# round::1, virtual_client::1, epoch::7, loss::0.016675174236297607, elps_time::0.9077439308166504.
# round::1, virtual_client::1, epoch::8, loss::0.016082696616649628, elps_time::0.8827645778656006.
# round::1, virtual_client::1, epoch::9, loss::0.011274946853518486, elps_time::0.8555123805999756.
# round::1, virtual_client::2, epoch::0, loss::0.011153576895594597, elps_time::0.9176609516143799.
# round::1, virtual_client::2, epoch::1, loss::0.005631308536976576, elps_time::0.9108624458312988.
# round::1, virtual_client::2, epoch::2, loss::0.005692126229405403, elps_time::0.9021461009979248.
# round::1, virtual_client::2, epoch::3, loss::0.0031107694376260042, elps_time::0.902026891708374.
# round::1, virtual_client::2, epoch::4, loss::0.00143612886313349, elps_time::0.8829784393310547.
# round::1, virtual_client::2, epoch::5, loss::0.003522876650094986, elps_time::0.9293825626373291.
# round::1, virtual_client::2, epoch::6, loss::0.014909721910953522, elps_time::0.888465166091919.
# round::1, virtual_client::2, epoch::7, loss::0.013315746560692787, elps_time::0.9712979793548584.
# round::1, virtual_client::2, epoch::8, loss::0.007372735999524593, elps_time::1.0072176456451416.
# round::1, virtual_client::2, epoch::9, loss::0.03016792982816696, elps_time::0.9335265159606934.
# round::1, virtual_client::3, epoch::0, loss::0.0012717440258711576, elps_time::0.8762423992156982.
# round::1, virtual_client::3, epoch::1, loss::0.003933853469789028, elps_time::0.8698382377624512.
# round::1, virtual_client::3, epoch::2, loss::0.03421084210276604, elps_time::0.8939428329467773.
# round::1, virtual_client::3, epoch::3, loss::0.007749469019472599, elps_time::0.876096248626709.
# round::1, virtual_client::3, epoch::4, loss::0.008035420440137386, elps_time::0.8905379772186279.
# round::1, virtual_client::3, epoch::5, loss::0.003989298362284899, elps_time::0.8512728214263916.
# round::1, virtual_client::3, epoch::6, loss::0.0020987242460250854, elps_time::0.8799519538879395.
# round::1, virtual_client::3, epoch::7, loss::0.005280094221234322, elps_time::0.8708803653717041.
# round::1, virtual_client::3, epoch::8, loss::0.006670303642749786, elps_time::0.858710527420044.
# round::1, virtual_client::3, epoch::9, loss::0.0056090280413627625, elps_time::0.8746883869171143.
# round::1, virtual_client::4, epoch::0, loss::0.10366252809762955, elps_time::0.8599121570587158.
# round::1, virtual_client::4, epoch::1, loss::0.01931772008538246, elps_time::0.871110200881958.
# round::1, virtual_client::4, epoch::2, loss::0.002093459712341428, elps_time::0.8641178607940674.
# round::1, virtual_client::4, epoch::3, loss::0.004685292486101389, elps_time::0.8761599063873291.
# round::1, virtual_client::4, epoch::4, loss::0.004637324251234531, elps_time::0.8870894908905029.
# round::1, virtual_client::4, epoch::5, loss::0.0235598124563694, elps_time::0.8932464122772217.
# round::1, virtual_client::4, epoch::6, loss::0.0012211562134325504, elps_time::0.8828775882720947.
# round::1, virtual_client::4, epoch::7, loss::0.0011616647243499756, elps_time::0.8853085041046143.
# round::1, virtual_client::4, epoch::8, loss::0.007165276445448399, elps_time::0.882460355758667.
# round::1, virtual_client::4, epoch::9, loss::0.00042695464799180627, elps_time::0.8564190864562988.
# round::1, virtual_client::5, epoch::0, loss::0.019163334742188454, elps_time::0.8797962665557861.
# round::1, virtual_client::5, epoch::1, loss::0.022190695628523827, elps_time::0.8697195053100586.
# round::1, virtual_client::5, epoch::2, loss::0.001869954983703792, elps_time::0.9373197555541992.
# round::1, virtual_client::5, epoch::3, loss::0.007591391447931528, elps_time::0.9913063049316406.
# round::1, virtual_client::5, epoch::4, loss::0.016687540337443352, elps_time::1.1892688274383545.
# round::1, virtual_client::5, epoch::5, loss::0.009555541910231113, elps_time::1.3029186725616455.
# round::1, virtual_client::5, epoch::6, loss::0.006787403021007776, elps_time::1.1355037689208984.
# round::1, virtual_client::5, epoch::7, loss::0.014740068465471268, elps_time::1.127634048461914.
# round::1, virtual_client::5, epoch::8, loss::0.005117360502481461, elps_time::1.1057274341583252.
# round::1, virtual_client::5, epoch::9, loss::0.003453743178397417, elps_time::1.0768465995788574.
# round::1, virtual_client::6, epoch::0, loss::0.035494230687618256, elps_time::1.0435540676116943.
# round::1, virtual_client::6, epoch::1, loss::0.07427936792373657, elps_time::1.0806243419647217.
# round::1, virtual_client::6, epoch::2, loss::0.0861206129193306, elps_time::1.0801763534545898.
# round::1, virtual_client::6, epoch::3, loss::0.08036017417907715, elps_time::1.0682811737060547.
# round::1, virtual_client::6, epoch::4, loss::0.047780051827430725, elps_time::1.0689146518707275.
# round::1, virtual_client::6, epoch::5, loss::0.01521479245275259, elps_time::1.0937163829803467.
# round::1, virtual_client::6, epoch::6, loss::0.01645650342106819, elps_time::1.075920581817627.
# round::1, virtual_client::6, epoch::7, loss::0.018430443480610847, elps_time::0.9878566265106201.
# round::1, virtual_client::6, epoch::8, loss::0.09078337252140045, elps_time::0.940086841583252.
# round::1, virtual_client::6, epoch::9, loss::0.014852041378617287, elps_time::0.9388535022735596.
# round::1, virtual_client::7, epoch::0, loss::0.05739854276180267, elps_time::0.8867208957672119.
# round::1, virtual_client::7, epoch::1, loss::0.03471650928258896, elps_time::0.9010977745056152.
# round::1, virtual_client::7, epoch::2, loss::0.04344744235277176, elps_time::0.8819465637207031.
# round::1, virtual_client::7, epoch::3, loss::0.028946097940206528, elps_time::0.8879809379577637.
# round::1, virtual_client::7, epoch::4, loss::0.0777510553598404, elps_time::0.9621655941009521.
# round::1, virtual_client::7, epoch::5, loss::0.021843206137418747, elps_time::0.936678409576416.
# round::1, virtual_client::7, epoch::6, loss::0.021229702979326248, elps_time::0.9677188396453857.
# round::1, virtual_client::7, epoch::7, loss::0.012643811292946339, elps_time::0.9639010429382324.
# round::1, virtual_client::7, epoch::8, loss::0.01753269135951996, elps_time::0.9622650146484375.
# round::1, virtual_client::7, epoch::9, loss::0.029362190514802933, elps_time::0.9204244613647461.
# round::1, virtual_client::8, epoch::0, loss::0.022180378437042236, elps_time::0.9102036952972412.
# round::1, virtual_client::8, epoch::1, loss::0.016013693064451218, elps_time::0.9200174808502197.
# round::1, virtual_client::8, epoch::2, loss::0.05110091716051102, elps_time::0.9058356285095215.
# round::1, virtual_client::8, epoch::3, loss::0.014784591272473335, elps_time::0.8948211669921875.
# round::1, virtual_client::8, epoch::4, loss::0.018595144152641296, elps_time::0.8982119560241699.
# round::1, virtual_client::8, epoch::5, loss::0.013276617974042892, elps_time::0.9049034118652344.
# round::1, virtual_client::8, epoch::6, loss::0.019517194479703903, elps_time::0.9076576232910156.
# round::1, virtual_client::8, epoch::7, loss::0.01568797044456005, elps_time::0.9128813743591309.
# round::1, virtual_client::8, epoch::8, loss::0.009123760275542736, elps_time::0.9499638080596924.
# round::1, virtual_client::8, epoch::9, loss::0.00950914528220892, elps_time::0.886815071105957.
# round::1, virtual_client::9, epoch::0, loss::7.510157047363464e-06, elps_time::0.7532167434692383.
# round::1, virtual_client::9, epoch::1, loss::0.7739339470863342, elps_time::0.7614717483520508.
# round::1, virtual_client::9, epoch::2, loss::0.00033623288618400693, elps_time::0.7313404083251953.
# round::1, virtual_client::9, epoch::3, loss::0.0003262225945945829, elps_time::0.7265927791595459.
# round::1, virtual_client::9, epoch::4, loss::0.00014423283573705703, elps_time::0.7267704010009766.
# round::1, virtual_client::9, epoch::5, loss::0.007895096205174923, elps_time::0.7414364814758301.
# round::1, virtual_client::9, epoch::6, loss::0.0005527398898266256, elps_time::0.7631375789642334.
# round::1, virtual_client::9, epoch::7, loss::0.0006211258587427437, elps_time::0.8130462169647217.
# round::1, virtual_client::9, epoch::8, loss::3.1470757676288486e-05, elps_time::0.7940685749053955.
# round::1, virtual_client::9, epoch::9, loss::0.14648012816905975, elps_time::0.7495148181915283.
# round::1 finished, test_acc::0.9309105277061462, elpsed time::96.71150255203247
# round::2, virtual_client::0, epoch::0, loss::0.010136066935956478, elps_time::0.8785927295684814.
# round::2, virtual_client::0, epoch::1, loss::0.024015771225094795, elps_time::0.8431422710418701.
# round::2, virtual_client::0, epoch::2, loss::0.028328128159046173, elps_time::0.8663585186004639.
# round::2, virtual_client::0, epoch::3, loss::0.01794079691171646, elps_time::0.8916172981262207.
# round::2, virtual_client::0, epoch::4, loss::0.013775577768683434, elps_time::0.8612613677978516.
# round::2, virtual_client::0, epoch::5, loss::0.01782008446753025, elps_time::0.8956997394561768.
# round::2, virtual_client::0, epoch::6, loss::0.010820579715073109, elps_time::0.8933897018432617.
# round::2, virtual_client::0, epoch::7, loss::0.01474175788462162, elps_time::0.8998613357543945.
# round::2, virtual_client::0, epoch::8, loss::0.021232064813375473, elps_time::0.8473067283630371.
# round::2, virtual_client::0, epoch::9, loss::0.011115256696939468, elps_time::0.8730072975158691.
# round::2, virtual_client::1, epoch::0, loss::0.0031494225841015577, elps_time::0.8990263938903809.
# round::2, virtual_client::1, epoch::1, loss::0.015413849614560604, elps_time::0.9093968868255615.
# round::2, virtual_client::1, epoch::2, loss::0.021775683388113976, elps_time::0.8769211769104004.
# round::2, virtual_client::1, epoch::3, loss::0.022444965317845345, elps_time::0.8787508010864258.
# round::2, virtual_client::1, epoch::4, loss::0.0022674337960779667, elps_time::0.9294426441192627.
# round::2, virtual_client::1, epoch::5, loss::0.012742225080728531, elps_time::0.9637699127197266.
# round::2, virtual_client::1, epoch::6, loss::0.011323688551783562, elps_time::1.0668976306915283.
# round::2, virtual_client::1, epoch::7, loss::0.012946946546435356, elps_time::1.2597239017486572.
# round::2, virtual_client::1, epoch::8, loss::0.013986848294734955, elps_time::1.299128532409668.
# round::2, virtual_client::1, epoch::9, loss::0.005705635063350201, elps_time::1.0693719387054443.
# round::2, virtual_client::2, epoch::0, loss::0.001412824960425496, elps_time::1.062760353088379.
# round::2, virtual_client::2, epoch::1, loss::0.000969488057307899, elps_time::1.0580530166625977.
# round::2, virtual_client::2, epoch::2, loss::0.0035576701629906893, elps_time::1.0581731796264648.
# round::2, virtual_client::2, epoch::3, loss::0.0031617521308362484, elps_time::1.0650110244750977.
# round::2, virtual_client::2, epoch::4, loss::0.0031705962028354406, elps_time::1.1129138469696045.
# round::2, virtual_client::2, epoch::5, loss::0.004313061013817787, elps_time::1.0938875675201416.
# round::2, virtual_client::2, epoch::6, loss::0.03343856707215309, elps_time::1.075803279876709.
# round::2, virtual_client::2, epoch::7, loss::0.0018273508176207542, elps_time::1.093794584274292.
# round::2, virtual_client::2, epoch::8, loss::0.008046100847423077, elps_time::1.1140305995941162.
# round::2, virtual_client::2, epoch::9, loss::0.0015468290075659752, elps_time::1.0828423500061035.
# round::2, virtual_client::3, epoch::0, loss::0.012445902451872826, elps_time::1.0321400165557861.
# round::2, virtual_client::3, epoch::1, loss::0.00293820071965456, elps_time::0.9311795234680176.
# round::2, virtual_client::3, epoch::2, loss::0.009373107925057411, elps_time::0.9564337730407715.
# round::2, virtual_client::3, epoch::3, loss::0.0011567019391804934, elps_time::0.9565985202789307.
# round::2, virtual_client::3, epoch::4, loss::0.028060631826519966, elps_time::0.9616513252258301.
# round::2, virtual_client::3, epoch::5, loss::0.002989004133269191, elps_time::1.004225730895996.
# round::2, virtual_client::3, epoch::6, loss::0.0066321128979325294, elps_time::0.9684967994689941.
# round::2, virtual_client::3, epoch::7, loss::0.003478914499282837, elps_time::0.9572577476501465.
# round::2, virtual_client::3, epoch::8, loss::0.0005826503038406372, elps_time::0.9441952705383301.
# round::2, virtual_client::3, epoch::9, loss::0.005756346974521875, elps_time::0.9401216506958008.
# round::2, virtual_client::4, epoch::0, loss::0.0018523487960919738, elps_time::0.9617254734039307.
# round::2, virtual_client::4, epoch::1, loss::0.0004193052591290325, elps_time::0.9025418758392334.
# round::2, virtual_client::4, epoch::2, loss::0.0003905133926309645, elps_time::0.904789924621582.
# round::2, virtual_client::4, epoch::3, loss::0.0005233905394561589, elps_time::0.9087061882019043.
# round::2, virtual_client::4, epoch::4, loss::0.03128443658351898, elps_time::0.9145123958587646.
# round::2, virtual_client::4, epoch::5, loss::0.003922007977962494, elps_time::0.9407916069030762.
# round::2, virtual_client::4, epoch::6, loss::0.03549479693174362, elps_time::0.906013011932373.
# round::2, virtual_client::4, epoch::7, loss::0.0018620959017425776, elps_time::1.01139235496521.
# round::2, virtual_client::4, epoch::8, loss::0.025076352059841156, elps_time::0.9078173637390137.
# round::2, virtual_client::4, epoch::9, loss::0.0003819247067440301, elps_time::1.1120953559875488.
# round::2, virtual_client::5, epoch::0, loss::0.0014092952478677034, elps_time::1.036708116531372.
# round::2, virtual_client::5, epoch::1, loss::0.0022184187546372414, elps_time::0.918729305267334.
# round::2, virtual_client::5, epoch::2, loss::0.0411074161529541, elps_time::0.8997697830200195.
# round::2, virtual_client::5, epoch::3, loss::0.003165043890476227, elps_time::0.8824977874755859.
# round::2, virtual_client::5, epoch::4, loss::0.006838410161435604, elps_time::0.9275760650634766.
# round::2, virtual_client::5, epoch::5, loss::0.0014949848409742117, elps_time::0.9443864822387695.
# round::2, virtual_client::5, epoch::6, loss::0.007545782253146172, elps_time::1.0271327495574951.
# round::2, virtual_client::5, epoch::7, loss::0.008328056894242764, elps_time::1.0692594051361084.
# round::2, virtual_client::5, epoch::8, loss::0.00538740074262023, elps_time::1.0423617362976074.
# round::2, virtual_client::5, epoch::9, loss::0.009721014648675919, elps_time::0.9253861904144287.
# round::2, virtual_client::6, epoch::0, loss::0.03927578777074814, elps_time::0.9537408351898193.
# round::2, virtual_client::6, epoch::1, loss::0.004145555663853884, elps_time::0.8992023468017578.
# round::2, virtual_client::6, epoch::2, loss::0.01464637741446495, elps_time::0.9099528789520264.
# round::2, virtual_client::6, epoch::3, loss::0.17432253062725067, elps_time::0.9224328994750977.
# round::2, virtual_client::6, epoch::4, loss::0.010245486162602901, elps_time::0.9521410465240479.
# round::2, virtual_client::6, epoch::5, loss::0.017256945371627808, elps_time::0.9055447578430176.
# round::2, virtual_client::6, epoch::6, loss::0.02014431171119213, elps_time::0.8886759281158447.
# round::2, virtual_client::6, epoch::7, loss::0.013105963356792927, elps_time::0.8893415927886963.
# round::2, virtual_client::6, epoch::8, loss::0.033489275723695755, elps_time::0.9001278877258301.
# round::2, virtual_client::6, epoch::9, loss::0.013229944743216038, elps_time::0.8671267032623291.
# round::2, virtual_client::7, epoch::0, loss::0.01219523698091507, elps_time::0.8280212879180908.
# round::2, virtual_client::7, epoch::1, loss::0.02501872181892395, elps_time::0.8833503723144531.
# round::2, virtual_client::7, epoch::2, loss::0.022196967154741287, elps_time::0.8698906898498535.
# round::2, virtual_client::7, epoch::3, loss::0.024250712245702744, elps_time::0.8676438331604004.
# round::2, virtual_client::7, epoch::4, loss::0.016219154000282288, elps_time::0.8734464645385742.
# round::2, virtual_client::7, epoch::5, loss::0.008273660205304623, elps_time::0.881345272064209.
# round::2, virtual_client::7, epoch::6, loss::0.010872353799641132, elps_time::0.9121053218841553.
# round::2, virtual_client::7, epoch::7, loss::0.01688740774989128, elps_time::0.9284310340881348.
# round::2, virtual_client::7, epoch::8, loss::0.013343681581318378, elps_time::0.8618826866149902.
# round::2, virtual_client::7, epoch::9, loss::0.017544228583574295, elps_time::0.8694429397583008.
# round::2, virtual_client::8, epoch::0, loss::0.006592677440494299, elps_time::0.8593289852142334.
# round::2, virtual_client::8, epoch::1, loss::0.016299108043313026, elps_time::0.880211353302002.
# round::2, virtual_client::8, epoch::2, loss::0.02543513849377632, elps_time::0.8475160598754883.
# round::2, virtual_client::8, epoch::3, loss::0.003901030868291855, elps_time::0.9804568290710449.
# round::2, virtual_client::8, epoch::4, loss::0.01302998699247837, elps_time::1.0491430759429932.
# round::2, virtual_client::8, epoch::5, loss::0.004478007555007935, elps_time::0.8455615043640137.
# round::2, virtual_client::8, epoch::6, loss::0.00389143917709589, elps_time::0.8172235488891602.
# round::2, virtual_client::8, epoch::7, loss::0.004208914469927549, elps_time::0.8723087310791016.
# round::2, virtual_client::8, epoch::8, loss::0.006582215894013643, elps_time::0.8902437686920166.
# round::2, virtual_client::8, epoch::9, loss::0.0030823403503745794, elps_time::0.8538818359375.
# round::2, virtual_client::9, epoch::0, loss::0.010887740179896355, elps_time::0.6894090175628662.
# round::2, virtual_client::9, epoch::1, loss::0.0004681444843299687, elps_time::0.694251537322998.
# round::2, virtual_client::9, epoch::2, loss::0.00022492263815365732, elps_time::0.6852617263793945.
# round::2, virtual_client::9, epoch::3, loss::8.666139910928905e-05, elps_time::0.6649265289306641.
# round::2, virtual_client::9, epoch::4, loss::4.887569048150908e-06, elps_time::0.6781065464019775.
# round::2, virtual_client::9, epoch::5, loss::1.549708758830093e-05, elps_time::0.7206528186798096.
# round::2, virtual_client::9, epoch::6, loss::5.578839045483619e-05, elps_time::0.7133285999298096.
# round::2, virtual_client::9, epoch::7, loss::0.01648343913257122, elps_time::0.686112642288208.
# round::2, virtual_client::9, epoch::8, loss::0.0002746204845607281, elps_time::0.7270870208740234.
# round::2, virtual_client::9, epoch::9, loss::4.0531076592742465e-06, elps_time::0.7077264785766602.
# round::2 finished, test_acc::0.9717451930046082, elpsed time::98.10818481445312
# round::3, virtual_client::0, epoch::0, loss::0.013832351192831993, elps_time::1.1078433990478516.
# round::3, virtual_client::0, epoch::1, loss::0.017198260873556137, elps_time::1.0888373851776123.
# round::3, virtual_client::0, epoch::2, loss::0.012532548978924751, elps_time::1.0844721794128418.
# round::3, virtual_client::0, epoch::3, loss::0.009997118264436722, elps_time::1.0806605815887451.
# round::3, virtual_client::0, epoch::4, loss::0.008972513489425182, elps_time::1.0957341194152832.
# round::3, virtual_client::0, epoch::5, loss::0.015523461624979973, elps_time::1.0811069011688232.
# round::3, virtual_client::0, epoch::6, loss::0.00380119145847857, elps_time::1.0868852138519287.
# round::3, virtual_client::0, epoch::7, loss::0.01313489954918623, elps_time::1.0992670059204102.
# round::3, virtual_client::0, epoch::8, loss::0.009628113359212875, elps_time::1.0595271587371826.
# round::3, virtual_client::0, epoch::9, loss::0.007059691473841667, elps_time::1.0840094089508057.
# round::3, virtual_client::1, epoch::0, loss::0.005037932191044092, elps_time::1.0958664417266846.
# round::3, virtual_client::1, epoch::1, loss::0.006410803180187941, elps_time::0.9646382331848145.
# round::3, virtual_client::1, epoch::2, loss::0.004471734631806612, elps_time::0.9986703395843506.
# round::3, virtual_client::1, epoch::3, loss::0.005506837274879217, elps_time::0.9568934440612793.
# round::3, virtual_client::1, epoch::4, loss::0.009055851958692074, elps_time::0.9119176864624023.
# round::3, virtual_client::1, epoch::5, loss::0.012384855188429356, elps_time::0.9040374755859375.
# round::3, virtual_client::1, epoch::6, loss::0.006820028647780418, elps_time::0.8771388530731201.
# round::3, virtual_client::1, epoch::7, loss::0.007420539390295744, elps_time::0.8770489692687988.
# round::3, virtual_client::1, epoch::8, loss::0.0018782876431941986, elps_time::0.8918774127960205.
# round::3, virtual_client::1, epoch::9, loss::0.0019236616790294647, elps_time::0.9623017311096191.
# round::3, virtual_client::2, epoch::0, loss::0.0006094520213082433, elps_time::1.0170354843139648.
# round::3, virtual_client::2, epoch::1, loss::0.0028073161374777555, elps_time::0.9724884033203125.
# round::3, virtual_client::2, epoch::2, loss::0.010018771514296532, elps_time::0.9292104244232178.
# round::3, virtual_client::2, epoch::3, loss::0.0026801470667123795, elps_time::0.878993034362793.
# round::3, virtual_client::2, epoch::4, loss::0.014044389128684998, elps_time::0.895251989364624.
# round::3, virtual_client::2, epoch::5, loss::0.005269361659884453, elps_time::0.9168164730072021.
# round::3, virtual_client::2, epoch::6, loss::0.006088703870773315, elps_time::0.8878154754638672.
# round::3, virtual_client::2, epoch::7, loss::0.006626184098422527, elps_time::0.8749196529388428.
# round::3, virtual_client::2, epoch::8, loss::0.00480321841314435, elps_time::0.8791384696960449.
# round::3, virtual_client::2, epoch::9, loss::0.0006520509487017989, elps_time::0.8886537551879883.
# round::3, virtual_client::3, epoch::0, loss::0.0012144880602136254, elps_time::0.8336412906646729.
# round::3, virtual_client::3, epoch::1, loss::0.003066031262278557, elps_time::0.8417925834655762.
# round::3, virtual_client::3, epoch::2, loss::0.007698512636125088, elps_time::0.8253545761108398.
# round::3, virtual_client::3, epoch::3, loss::0.00040878175059333444, elps_time::0.8351166248321533.
# round::3, virtual_client::3, epoch::4, loss::0.0005923970602452755, elps_time::0.8350880146026611.
# round::3, virtual_client::3, epoch::5, loss::0.01230359636247158, elps_time::0.8241369724273682.
# round::3, virtual_client::3, epoch::6, loss::0.0005894885398447514, elps_time::0.8785066604614258.
# round::3, virtual_client::3, epoch::7, loss::0.010925021953880787, elps_time::0.8881382942199707.
# round::3, virtual_client::3, epoch::8, loss::0.0018554760608822107, elps_time::0.8713226318359375.
# round::3, virtual_client::3, epoch::9, loss::0.005424718838185072, elps_time::0.8479716777801514.
# round::3, virtual_client::4, epoch::0, loss::0.0003390130295883864, elps_time::0.8681244850158691.
# round::3, virtual_client::4, epoch::1, loss::0.004331824369728565, elps_time::0.8518068790435791.
# round::3, virtual_client::4, epoch::2, loss::0.00043420534348115325, elps_time::0.8474481105804443.
# round::3, virtual_client::4, epoch::3, loss::0.00976844597607851, elps_time::0.8493545055389404.
# round::3, virtual_client::4, epoch::4, loss::0.005020283628255129, elps_time::0.8427956104278564.
# round::3, virtual_client::4, epoch::5, loss::0.00019718188559636474, elps_time::0.8686444759368896.
# round::3, virtual_client::4, epoch::6, loss::0.004652511794120073, elps_time::0.8752491474151611.
# round::3, virtual_client::4, epoch::7, loss::0.0029663373716175556, elps_time::0.9683704376220703.
# round::3, virtual_client::4, epoch::8, loss::0.015204228460788727, elps_time::1.1700031757354736.
# round::3, virtual_client::4, epoch::9, loss::0.0013210722245275974, elps_time::0.893507719039917.
# round::3, virtual_client::5, epoch::0, loss::0.0019313476514071226, elps_time::0.8287770748138428.
# round::3, virtual_client::5, epoch::1, loss::0.004379316233098507, elps_time::0.8460938930511475.
# round::3, virtual_client::5, epoch::2, loss::0.0006188579136505723, elps_time::0.8759267330169678.
# round::3, virtual_client::5, epoch::3, loss::0.007902964018285275, elps_time::0.8394756317138672.
# round::3, virtual_client::5, epoch::4, loss::0.007790327537804842, elps_time::0.8487045764923096.
# round::3, virtual_client::5, epoch::5, loss::0.0131176533177495, elps_time::0.8284471035003662.
# round::3, virtual_client::5, epoch::6, loss::0.004659377969801426, elps_time::0.8547065258026123.
# round::3, virtual_client::5, epoch::7, loss::0.008554276078939438, elps_time::0.8682882785797119.
# round::3, virtual_client::5, epoch::8, loss::0.0016377296997234225, elps_time::0.8623371124267578.
# round::3, virtual_client::5, epoch::9, loss::0.0008398062200285494, elps_time::0.9663193225860596.
# round::3, virtual_client::6, epoch::0, loss::0.005126923322677612, elps_time::0.8732235431671143.
# round::3, virtual_client::6, epoch::1, loss::0.01755182258784771, elps_time::0.8634552955627441.
# round::3, virtual_client::6, epoch::2, loss::0.0010679762344807386, elps_time::0.9013862609863281.
# round::3, virtual_client::6, epoch::3, loss::0.008192237466573715, elps_time::0.891791582107544.
# round::3, virtual_client::6, epoch::4, loss::0.004159465432167053, elps_time::0.8539955615997314.
# round::3, virtual_client::6, epoch::5, loss::0.008926225826144218, elps_time::0.8704230785369873.
# round::3, virtual_client::6, epoch::6, loss::0.004934985656291246, elps_time::1.042933464050293.
# round::3, virtual_client::6, epoch::7, loss::0.008173778653144836, elps_time::1.0619471073150635.
# round::3, virtual_client::6, epoch::8, loss::0.005065074656158686, elps_time::1.0774891376495361.
# round::3, virtual_client::6, epoch::9, loss::0.0031049558892846107, elps_time::1.0689940452575684.
# round::3, virtual_client::7, epoch::0, loss::0.014634429477155209, elps_time::1.053609848022461.
# round::3, virtual_client::7, epoch::1, loss::0.004931184463202953, elps_time::1.0310146808624268.
# round::3, virtual_client::7, epoch::2, loss::0.012839214876294136, elps_time::1.0585181713104248.
# round::3, virtual_client::7, epoch::3, loss::0.00928235799074173, elps_time::1.0623204708099365.
# round::3, virtual_client::7, epoch::4, loss::0.005865585524588823, elps_time::1.0708653926849365.
# round::3, virtual_client::7, epoch::5, loss::0.014608997851610184, elps_time::1.055070161819458.
# round::3, virtual_client::7, epoch::6, loss::0.015304528176784515, elps_time::1.0389132499694824.
# round::3, virtual_client::7, epoch::7, loss::0.0067505245096981525, elps_time::1.033722162246704.
# round::3, virtual_client::7, epoch::8, loss::0.003984204027801752, elps_time::1.056466817855835.
# round::3, virtual_client::7, epoch::9, loss::0.003498974721878767, elps_time::1.047943353652954.
# round::3, virtual_client::8, epoch::0, loss::0.038954395800828934, elps_time::1.0266835689544678.
# round::3, virtual_client::8, epoch::1, loss::0.025776289403438568, elps_time::1.0339140892028809.
# round::3, virtual_client::8, epoch::2, loss::0.009248173795640469, elps_time::0.9325037002563477.
# round::3, virtual_client::8, epoch::3, loss::0.007706847973167896, elps_time::0.8657820224761963.
# round::3, virtual_client::8, epoch::4, loss::0.004841899499297142, elps_time::0.8655824661254883.
# round::3, virtual_client::8, epoch::5, loss::0.00618622824549675, elps_time::0.8833053112030029.
# round::3, virtual_client::8, epoch::6, loss::0.00763847678899765, elps_time::0.8559951782226562.
# round::3, virtual_client::8, epoch::7, loss::0.004499970935285091, elps_time::0.9203803539276123.
# round::3, virtual_client::8, epoch::8, loss::0.004102631472051144, elps_time::0.9433033466339111.
# round::3, virtual_client::8, epoch::9, loss::0.005973045714199543, elps_time::0.9764194488525391.
# round::3, virtual_client::9, epoch::0, loss::0.000243634101934731, elps_time::0.894157886505127.
# round::3, virtual_client::9, epoch::1, loss::1.7404405298293568e-05, elps_time::0.7519614696502686.
# round::3, virtual_client::9, epoch::2, loss::4.458328112377785e-05, elps_time::0.8016903400421143.
# round::3, virtual_client::9, epoch::3, loss::0.0004786299541592598, elps_time::0.7396955490112305.
# round::3, virtual_client::9, epoch::4, loss::6.496695277746767e-05, elps_time::0.7376999855041504.
# round::3, virtual_client::9, epoch::5, loss::1.6212332411669195e-05, elps_time::0.7261373996734619.
# round::3, virtual_client::9, epoch::6, loss::0.00013886917440686375, elps_time::0.7197427749633789.
# round::3, virtual_client::9, epoch::7, loss::5.090107151772827e-05, elps_time::0.728649377822876.
# round::3, virtual_client::9, epoch::8, loss::2.95634672511369e-05, elps_time::0.7160241603851318.
# round::3, virtual_client::9, epoch::9, loss::1.0728830375228426e-06, elps_time::0.7165331840515137.
# round::3 finished, test_acc::0.9746405482292175, elpsed time::97.07079339027405
# round::4, virtual_client::0, epoch::0, loss::0.015169549733400345, elps_time::0.8225877285003662.
# round::4, virtual_client::0, epoch::1, loss::0.007310270797461271, elps_time::0.8532190322875977.
# round::4, virtual_client::0, epoch::2, loss::0.00812290608882904, elps_time::0.8670575618743896.
# round::4, virtual_client::0, epoch::3, loss::0.006889220792800188, elps_time::0.8585970401763916.
# round::4, virtual_client::0, epoch::4, loss::0.01583997532725334, elps_time::0.8533942699432373.
# round::4, virtual_client::0, epoch::5, loss::0.008824409916996956, elps_time::0.8457465171813965.
# round::4, virtual_client::0, epoch::6, loss::0.006816107779741287, elps_time::0.853100061416626.
# round::4, virtual_client::0, epoch::7, loss::0.007925344631075859, elps_time::0.8443779945373535.
# round::4, virtual_client::0, epoch::8, loss::0.008390730246901512, elps_time::0.872014045715332.
# round::4, virtual_client::0, epoch::9, loss::0.003087845165282488, elps_time::0.9276530742645264.
# round::4, virtual_client::1, epoch::0, loss::0.00069400918437168, elps_time::0.9597134590148926.
# round::4, virtual_client::1, epoch::1, loss::0.006240591872483492, elps_time::0.8836257457733154.
# round::4, virtual_client::1, epoch::2, loss::0.006183966062963009, elps_time::1.0333471298217773.
# round::4, virtual_client::1, epoch::3, loss::0.006847918499261141, elps_time::1.1224732398986816.
# round::4, virtual_client::1, epoch::4, loss::0.005675007123500109, elps_time::0.8591208457946777.
# round::4, virtual_client::1, epoch::5, loss::0.00580174895003438, elps_time::0.85683274269104.
# round::4, virtual_client::1, epoch::6, loss::0.005146294366568327, elps_time::0.8364582061767578.
# round::4, virtual_client::1, epoch::7, loss::0.003444481175392866, elps_time::0.9098131656646729.
# round::4, virtual_client::1, epoch::8, loss::0.004195265471935272, elps_time::0.8420026302337646.
# round::4, virtual_client::1, epoch::9, loss::0.004321234300732613, elps_time::0.8432166576385498.
# round::4, virtual_client::2, epoch::0, loss::0.0024437732063233852, elps_time::0.8786938190460205.
# round::4, virtual_client::2, epoch::1, loss::0.0045774043537676334, elps_time::0.8777222633361816.
# round::4, virtual_client::2, epoch::2, loss::0.002675759606063366, elps_time::0.8690810203552246.
# round::4, virtual_client::2, epoch::3, loss::0.004756682552397251, elps_time::0.868849515914917.
# round::4, virtual_client::2, epoch::4, loss::0.0013615407515317202, elps_time::0.9027457237243652.
# round::4, virtual_client::2, epoch::5, loss::0.002939115045592189, elps_time::0.8899202346801758.
# round::4, virtual_client::2, epoch::6, loss::0.0011223466135561466, elps_time::0.8815913200378418.
# round::4, virtual_client::2, epoch::7, loss::0.005139484070241451, elps_time::0.8534355163574219.
# round::4, virtual_client::2, epoch::8, loss::0.003906949423253536, elps_time::0.8267953395843506.
# round::4, virtual_client::2, epoch::9, loss::0.0008908148156479001, elps_time::0.8121187686920166.
# round::4, virtual_client::3, epoch::0, loss::0.0004762587486766279, elps_time::0.853879451751709.
# round::4, virtual_client::3, epoch::1, loss::0.006614089012145996, elps_time::1.082535743713379.
# round::4, virtual_client::3, epoch::2, loss::0.00493394210934639, elps_time::1.1042242050170898.
# round::4, virtual_client::3, epoch::3, loss::0.0005213383119553328, elps_time::1.0880041122436523.
# round::4, virtual_client::3, epoch::4, loss::0.006990900728851557, elps_time::1.0743634700775146.
# round::4, virtual_client::3, epoch::5, loss::0.0009457619162276387, elps_time::1.0406157970428467.
# round::4, virtual_client::3, epoch::6, loss::0.0013429755344986916, elps_time::1.0681195259094238.
# round::4, virtual_client::3, epoch::7, loss::0.0015984672354534268, elps_time::1.0515549182891846.
# round::4, virtual_client::3, epoch::8, loss::0.002633676864206791, elps_time::1.06589674949646.
# round::4, virtual_client::3, epoch::9, loss::0.0029102012049406767, elps_time::1.0521306991577148.
# round::4, virtual_client::4, epoch::0, loss::0.01416083611547947, elps_time::1.1201610565185547.
# round::4, virtual_client::4, epoch::1, loss::0.000196333639905788, elps_time::1.0890424251556396.
# round::4, virtual_client::4, epoch::2, loss::0.004011818673461676, elps_time::1.0636050701141357.
# round::4, virtual_client::4, epoch::3, loss::0.0008172870147973299, elps_time::1.074889898300171.
# round::4, virtual_client::4, epoch::4, loss::0.00020311199477873743, elps_time::1.0339553356170654.
# round::4, virtual_client::4, epoch::5, loss::0.003568748477846384, elps_time::0.9666104316711426.
# round::4, virtual_client::4, epoch::6, loss::0.0035317607689648867, elps_time::1.002650260925293.
# round::4, virtual_client::4, epoch::7, loss::0.0016685978043824434, elps_time::0.8612852096557617.
# round::4, virtual_client::4, epoch::8, loss::0.0037640787195414305, elps_time::0.8800392150878906.
# round::4, virtual_client::4, epoch::9, loss::0.005237065255641937, elps_time::0.888563871383667.
# round::4, virtual_client::5, epoch::0, loss::0.0005303091602399945, elps_time::0.8813025951385498.
# round::4, virtual_client::5, epoch::1, loss::0.0029739816673099995, elps_time::0.910250186920166.
# round::4, virtual_client::5, epoch::2, loss::0.00032469112193211913, elps_time::0.9655265808105469.
# round::4, virtual_client::5, epoch::3, loss::0.0028023160994052887, elps_time::1.031447410583496.
# round::4, virtual_client::5, epoch::4, loss::0.002119372133165598, elps_time::1.0349431037902832.
# round::4, virtual_client::5, epoch::5, loss::0.013024010695517063, elps_time::0.9933443069458008.
# round::4, virtual_client::5, epoch::6, loss::0.004517358727753162, elps_time::0.9319198131561279.
# round::4, virtual_client::5, epoch::7, loss::0.00151835847645998, elps_time::0.9448592662811279.
# round::4, virtual_client::5, epoch::8, loss::0.007352366112172604, elps_time::0.8919825553894043.
# round::4, virtual_client::5, epoch::9, loss::0.0015080703888088465, elps_time::0.8884882926940918.
# round::4, virtual_client::6, epoch::0, loss::0.0030158571898937225, elps_time::0.9239456653594971.
# round::4, virtual_client::6, epoch::1, loss::0.004189074970781803, elps_time::0.9664866924285889.
# round::4, virtual_client::6, epoch::2, loss::0.0048840781673789024, elps_time::0.9330909252166748.
# round::4, virtual_client::6, epoch::3, loss::0.013069063425064087, elps_time::0.9005568027496338.
# round::4, virtual_client::6, epoch::4, loss::0.0020715987775474787, elps_time::0.8940844535827637.
# round::4, virtual_client::6, epoch::5, loss::0.014991333708167076, elps_time::0.8889620304107666.
# round::4, virtual_client::6, epoch::6, loss::0.006069140508770943, elps_time::0.9087932109832764.
# round::4, virtual_client::6, epoch::7, loss::0.003354688873514533, elps_time::0.8617379665374756.
# round::4, virtual_client::6, epoch::8, loss::0.0016120719956234097, elps_time::0.9035167694091797.
# round::4, virtual_client::6, epoch::9, loss::0.003688650671392679, elps_time::0.8873927593231201.
# round::4, virtual_client::7, epoch::0, loss::0.0017469747690483928, elps_time::0.8744962215423584.
# round::4, virtual_client::7, epoch::1, loss::0.008548134006559849, elps_time::0.8969910144805908.
# round::4, virtual_client::7, epoch::2, loss::0.018611066043376923, elps_time::0.8951461315155029.
# round::4, virtual_client::7, epoch::3, loss::0.00982758216559887, elps_time::0.9379470348358154.
# round::4, virtual_client::7, epoch::4, loss::0.005459184758365154, elps_time::0.9033281803131104.
# round::4, virtual_client::7, epoch::5, loss::0.004762308672070503, elps_time::0.8329699039459229.
# round::4, virtual_client::7, epoch::6, loss::0.00325643178075552, elps_time::0.9142072200775146.
# round::4, virtual_client::7, epoch::7, loss::0.004709587898105383, elps_time::0.8608741760253906.
# round::4, virtual_client::7, epoch::8, loss::0.00865575298666954, elps_time::0.8781976699829102.
# round::4, virtual_client::7, epoch::9, loss::0.0031989251729100943, elps_time::0.9589409828186035.
# round::4, virtual_client::8, epoch::0, loss::0.025464892387390137, elps_time::1.10304856300354.
# round::4, virtual_client::8, epoch::1, loss::0.00364511925727129, elps_time::0.9817149639129639.
# round::4, virtual_client::8, epoch::2, loss::0.00614164536818862, elps_time::0.8626422882080078.
# round::4, virtual_client::8, epoch::3, loss::0.003255000337958336, elps_time::0.8825695514678955.
# round::4, virtual_client::8, epoch::4, loss::0.0020402134396135807, elps_time::0.9402215480804443.
# round::4, virtual_client::8, epoch::5, loss::0.0025606234557926655, elps_time::0.8894093036651611.
# round::4, virtual_client::8, epoch::6, loss::0.00489388220012188, elps_time::0.8801050186157227.
# ...
# round::18, virtual_client::4, epoch::1, loss::0.0001387459342367947, elps_time::0.915428638458252.
# round::18, virtual_client::4, epoch::2, loss::7.422948692692444e-05, elps_time::0.898679256439209.
# round::18, virtual_client::4, epoch::3, loss::0.0009915523696690798, elps_time::0.9438636302947998.
# round::18, virtual_client::4, epoch::4, loss::0.005272844806313515, elps_time::0.8931355476379395.
# round::18, virtual_client::4, epoch::5, loss::0.0018175720470026135, elps_time::0.8569042682647705.
# round::18, virtual_client::4, epoch::6, loss::0.0014239762676879764, elps_time::0.9675266742706299.
# round::18, virtual_client::4, epoch::7, loss::0.00044895094470120966, elps_time::0.9271540641784668.
# round::18, virtual_client::4, epoch::8, loss::0.006948953494429588, elps_time::0.925823450088501.
# round::18, virtual_client::4, epoch::9, loss::0.00040573213482275605, elps_time::0.9015731811523438.
# round::18, virtual_client::5, epoch::0, loss::0.0028554906602948904, elps_time::0.9071650505065918.
# round::18, virtual_client::5, epoch::1, loss::0.004816976375877857, elps_time::0.870908260345459.
# round::18, virtual_client::5, epoch::2, loss::0.003010539337992668, elps_time::0.8742613792419434.
# round::18, virtual_client::5, epoch::3, loss::0.0023802691139280796, elps_time::0.9086811542510986.
# round::18, virtual_client::5, epoch::4, loss::0.0016122226370498538, elps_time::0.8604977130889893.
# round::18, virtual_client::5, epoch::5, loss::0.0017286301590502262, elps_time::0.8922722339630127.
# round::18, virtual_client::5, epoch::6, loss::0.0010189478052780032, elps_time::0.8456242084503174.
# round::18, virtual_client::5, epoch::7, loss::0.0018985879141837358, elps_time::0.8519802093505859.
# round::18, virtual_client::5, epoch::8, loss::0.001018725335597992, elps_time::0.9465842247009277.
# round::18, virtual_client::5, epoch::9, loss::0.0035354644060134888, elps_time::1.0726568698883057.
# round::18, virtual_client::6, epoch::0, loss::0.0038605299778282642, elps_time::0.9281048774719238.
# round::18, virtual_client::6, epoch::1, loss::0.0012358600506559014, elps_time::0.9255802631378174.
# round::18, virtual_client::6, epoch::2, loss::0.0022763987071812153, elps_time::0.9600009918212891.
# round::18, virtual_client::6, epoch::3, loss::0.002720882184803486, elps_time::0.9310088157653809.
# round::18, virtual_client::6, epoch::4, loss::0.003834446659311652, elps_time::0.9611988067626953.
# round::18, virtual_client::6, epoch::5, loss::0.0018298852955922484, elps_time::1.2210416793823242.
# round::18, virtual_client::6, epoch::6, loss::0.006651289761066437, elps_time::1.0680310726165771.
# round::18, virtual_client::6, epoch::7, loss::0.000987434177659452, elps_time::0.9286234378814697.
# round::18, virtual_client::6, epoch::8, loss::0.0027913658414036036, elps_time::0.9697129726409912.
# round::18, virtual_client::6, epoch::9, loss::0.0017085934523493052, elps_time::0.9842512607574463.
# round::18, virtual_client::7, epoch::0, loss::0.001241202000528574, elps_time::0.9774975776672363.
# round::18, virtual_client::7, epoch::1, loss::0.0021016020327806473, elps_time::1.0896401405334473.
# round::18, virtual_client::7, epoch::2, loss::0.004360681399703026, elps_time::0.9864366054534912.
# round::18, virtual_client::7, epoch::3, loss::0.001945468713529408, elps_time::1.2655882835388184.
# round::18, virtual_client::7, epoch::4, loss::0.003620082512497902, elps_time::1.3926334381103516.
# round::18, virtual_client::7, epoch::5, loss::0.001966061070561409, elps_time::1.3785207271575928.
# round::18, virtual_client::7, epoch::6, loss::0.0027214400470256805, elps_time::1.1786572933197021.
# round::18, virtual_client::7, epoch::7, loss::0.0015277378261089325, elps_time::1.2006504535675049.
# round::18, virtual_client::7, epoch::8, loss::0.001015363959595561, elps_time::1.1919405460357666.
# round::18, virtual_client::7, epoch::9, loss::0.003752955701202154, elps_time::1.1852476596832275.
# round::18, virtual_client::8, epoch::0, loss::0.002038788516074419, elps_time::1.1226983070373535.
# round::18, virtual_client::8, epoch::1, loss::0.002992329653352499, elps_time::1.142218828201294.
# round::18, virtual_client::8, epoch::2, loss::0.0018761538667604327, elps_time::1.1518442630767822.
# round::18, virtual_client::8, epoch::3, loss::0.0028703310526907444, elps_time::1.1839039325714111.
# round::18, virtual_client::8, epoch::4, loss::0.0030160013120621443, elps_time::1.1440708637237549.
# round::18, virtual_client::8, epoch::5, loss::0.0020600706338882446, elps_time::1.1677677631378174.
# round::18, virtual_client::8, epoch::6, loss::0.0016757081029936671, elps_time::1.21307373046875.
# round::18, virtual_client::8, epoch::7, loss::0.001630008453503251, elps_time::1.1785502433776855.
# round::18, virtual_client::8, epoch::8, loss::0.0034584023524075747, elps_time::1.0938687324523926.
# round::18, virtual_client::8, epoch::9, loss::0.001707273069769144, elps_time::1.0428714752197266.
# round::18, virtual_client::9, epoch::0, loss::5.006777428206988e-06, elps_time::0.8836586475372314.
# round::18, virtual_client::9, epoch::1, loss::4.887569048150908e-06, elps_time::0.8588614463806152.
# round::18, virtual_client::9, epoch::2, loss::0.00013815402053296566, elps_time::0.8253142833709717.
# round::18, virtual_client::9, epoch::3, loss::3.0874729418428615e-05, elps_time::0.890899658203125.
# round::18, virtual_client::9, epoch::4, loss::1.3112935448589269e-05, elps_time::1.0941226482391357.
# round::18, virtual_client::9, epoch::5, loss::0.00011574551899684593, elps_time::1.051642656326294.
# round::18, virtual_client::9, epoch::6, loss::1.549708758830093e-05, elps_time::1.1631889343261719.
# round::18, virtual_client::9, epoch::7, loss::5.960462772236497e-07, elps_time::1.0690374374389648.
# round::18, virtual_client::9, epoch::8, loss::1.311301275563892e-06, elps_time::1.1318449974060059.
# round::18, virtual_client::9, epoch::9, loss::8.940656698541716e-06, elps_time::0.8808066844940186.
# round::18 finished, test_acc::0.9844249486923218, elpsed time::106.66978478431702
# round::19, virtual_client::0, epoch::0, loss::0.003255948657169938, elps_time::1.028040885925293.
# round::19, virtual_client::0, epoch::1, loss::0.002267405390739441, elps_time::0.9699697494506836.
# round::19, virtual_client::0, epoch::2, loss::0.003461529966443777, elps_time::0.9760031700134277.
# round::19, virtual_client::0, epoch::3, loss::0.003235361771658063, elps_time::0.946077823638916.
# round::19, virtual_client::0, epoch::4, loss::0.0026521794497966766, elps_time::0.9469895362854004.
# round::19, virtual_client::0, epoch::5, loss::0.002733041299507022, elps_time::0.9355800151824951.
# round::19, virtual_client::0, epoch::6, loss::0.0026209678035229445, elps_time::0.9177851676940918.
# round::19, virtual_client::0, epoch::7, loss::0.00226848223246634, elps_time::0.9672605991363525.
# round::19, virtual_client::0, epoch::8, loss::0.00455989595502615, elps_time::0.9822158813476562.
# round::19, virtual_client::0, epoch::9, loss::0.0017552217468619347, elps_time::1.0201621055603027.
# round::19, virtual_client::1, epoch::0, loss::0.0006023244932293892, elps_time::1.0058584213256836.
# round::19, virtual_client::1, epoch::1, loss::0.003350034123286605, elps_time::0.9407732486724854.
# round::19, virtual_client::1, epoch::2, loss::0.0023710199166089296, elps_time::0.9495978355407715.
# round::19, virtual_client::1, epoch::3, loss::0.0015255799517035484, elps_time::0.9134845733642578.
# round::19, virtual_client::1, epoch::4, loss::0.0028623659163713455, elps_time::0.9031796455383301.
# round::19, virtual_client::1, epoch::5, loss::0.0034501582849770784, elps_time::0.9307129383087158.
# round::19, virtual_client::1, epoch::6, loss::0.0018786736764013767, elps_time::0.9277739524841309.
# round::19, virtual_client::1, epoch::7, loss::0.0020723524503409863, elps_time::0.9073302745819092.
# round::19, virtual_client::1, epoch::8, loss::0.004411695525050163, elps_time::0.9009265899658203.
# round::19, virtual_client::1, epoch::9, loss::0.0024987333454191685, elps_time::0.9630002975463867.
# round::19, virtual_client::2, epoch::0, loss::0.020282158628106117, elps_time::1.288447618484497.
# round::19, virtual_client::2, epoch::1, loss::0.0009519452578388155, elps_time::1.0430560111999512.
# round::19, virtual_client::2, epoch::2, loss::0.0005582338199019432, elps_time::0.942885160446167.
# round::19, virtual_client::2, epoch::3, loss::0.0015526931965723634, elps_time::0.9232461452484131.
# round::19, virtual_client::2, epoch::4, loss::0.0018064368050545454, elps_time::0.8910439014434814.
# round::19, virtual_client::2, epoch::5, loss::0.0012139889877289534, elps_time::0.9370880126953125.
# round::19, virtual_client::2, epoch::6, loss::0.00244006491266191, elps_time::0.9165635108947754.
# round::19, virtual_client::2, epoch::7, loss::0.0005101179704070091, elps_time::0.9286599159240723.
# round::19, virtual_client::2, epoch::8, loss::0.0013389504747465253, elps_time::0.9377901554107666.
# round::19, virtual_client::2, epoch::9, loss::0.002165440237149596, elps_time::1.150451421737671.
# round::19, virtual_client::3, epoch::0, loss::0.007140452973544598, elps_time::1.2323050498962402.
# round::19, virtual_client::3, epoch::1, loss::0.0032822268549352884, elps_time::1.1734497547149658.
# round::19, virtual_client::3, epoch::2, loss::0.003054267494007945, elps_time::1.01613450050354.
# round::19, virtual_client::3, epoch::3, loss::0.0005180761218070984, elps_time::1.0871570110321045.
# round::19, virtual_client::3, epoch::4, loss::0.0007077099871821702, elps_time::1.1604201793670654.
# round::19, virtual_client::3, epoch::5, loss::0.0006620398489758372, elps_time::1.171414852142334.
# round::19, virtual_client::3, epoch::6, loss::0.0005456052022054791, elps_time::1.1912600994110107.
# round::19, virtual_client::3, epoch::7, loss::0.0020622634328901768, elps_time::1.1838910579681396.
# round::19, virtual_client::3, epoch::8, loss::0.0006778700626455247, elps_time::1.1852691173553467.
# round::19, virtual_client::3, epoch::9, loss::0.0006067691720090806, elps_time::1.1735315322875977.
# round::19, virtual_client::4, epoch::0, loss::0.001293908222578466, elps_time::1.1805450916290283.
# round::19, virtual_client::4, epoch::1, loss::0.0022251529153436422, elps_time::1.1989526748657227.
# round::19, virtual_client::4, epoch::2, loss::0.0047432612627744675, elps_time::1.1648995876312256.
# round::19, virtual_client::4, epoch::3, loss::0.005278320517390966, elps_time::1.0163476467132568.
# round::19, virtual_client::4, epoch::4, loss::0.0010535494657233357, elps_time::1.0202929973602295.
# round::19, virtual_client::4, epoch::5, loss::0.0006468234932981431, elps_time::0.9948525428771973.
# round::19, virtual_client::4, epoch::6, loss::0.0014574660453945398, elps_time::0.9854228496551514.
# round::19, virtual_client::4, epoch::7, loss::0.001577861374244094, elps_time::1.05375337600708.
# round::19, virtual_client::4, epoch::8, loss::0.0019446652149781585, elps_time::1.1011521816253662.
# round::19, virtual_client::4, epoch::9, loss::0.003194528864696622, elps_time::1.1433804035186768.
# round::19, virtual_client::5, epoch::0, loss::0.02036137506365776, elps_time::1.3377585411071777.
# round::19, virtual_client::5, epoch::1, loss::0.001242753816768527, elps_time::1.1674256324768066.
# round::19, virtual_client::5, epoch::2, loss::0.0021057361736893654, elps_time::1.3468680381774902.
# round::19, virtual_client::5, epoch::3, loss::0.001681419787928462, elps_time::1.344097375869751.
# round::19, virtual_client::5, epoch::4, loss::0.001338580041192472, elps_time::1.084122896194458.
# round::19, virtual_client::5, epoch::5, loss::0.0005307606188580394, elps_time::1.0372960567474365.
# round::19, virtual_client::5, epoch::6, loss::0.0026469072327017784, elps_time::1.0920417308807373.
# round::19, virtual_client::5, epoch::7, loss::0.0008421640377491713, elps_time::1.0747292041778564.
# round::19, virtual_client::5, epoch::8, loss::0.0004966820124536753, elps_time::1.0195088386535645.
# round::19, virtual_client::5, epoch::9, loss::0.0006258995272219181, elps_time::1.049147129058838.
# round::19, virtual_client::6, epoch::0, loss::0.0030740422662347555, elps_time::0.9957756996154785.
# round::19, virtual_client::6, epoch::1, loss::0.004247394390404224, elps_time::1.0413975715637207.
# round::19, virtual_client::6, epoch::2, loss::0.0018838951364159584, elps_time::0.9522790908813477.
# round::19, virtual_client::6, epoch::3, loss::0.00325798150151968, elps_time::0.9346222877502441.
# round::19, virtual_client::6, epoch::4, loss::0.003057916183024645, elps_time::0.9521656036376953.
# round::19, virtual_client::6, epoch::5, loss::0.001024953555315733, elps_time::0.9251294136047363.
# round::19, virtual_client::6, epoch::6, loss::0.001452343538403511, elps_time::0.946526050567627.
# round::19, virtual_client::6, epoch::7, loss::0.0020385945681482553, elps_time::0.9193570613861084.
# round::19, virtual_client::6, epoch::8, loss::0.002662899438291788, elps_time::0.923804759979248.
# round::19, virtual_client::6, epoch::9, loss::0.0012713393662124872, elps_time::0.9547398090362549.
# round::19, virtual_client::7, epoch::0, loss::0.004909601528197527, elps_time::0.9138638973236084.
# round::19, virtual_client::7, epoch::1, loss::0.0031229432206600904, elps_time::0.9033381938934326.
# round::19, virtual_client::7, epoch::2, loss::0.0031998855993151665, elps_time::0.9014313220977783.
# round::19, virtual_client::7, epoch::3, loss::0.0025573917664587498, elps_time::0.8963449001312256.
# round::19, virtual_client::7, epoch::4, loss::0.0013555735349655151, elps_time::0.9111933708190918.
# round::19, virtual_client::7, epoch::5, loss::0.0008339449996128678, elps_time::0.9103348255157471.
# round::19, virtual_client::7, epoch::6, loss::0.002700135810300708, elps_time::0.9374167919158936.
# round::19, virtual_client::7, epoch::7, loss::0.0036759693175554276, elps_time::0.9343934059143066.
# round::19, virtual_client::7, epoch::8, loss::0.003892966778948903, elps_time::0.9218027591705322.
# round::19, virtual_client::7, epoch::9, loss::0.0019374428084120154, elps_time::0.8847124576568604.
# round::19, virtual_client::8, epoch::0, loss::0.002078138990327716, elps_time::0.9231359958648682.
# round::19, virtual_client::8, epoch::1, loss::0.0027925358153879642, elps_time::1.05780029296875.
# round::19, virtual_client::8, epoch::2, loss::0.0011212462559342384, elps_time::1.0890288352966309.
# round::19, virtual_client::8, epoch::3, loss::0.002028462942689657, elps_time::0.8650455474853516.
# round::19, virtual_client::8, epoch::4, loss::0.0015916889533400536, elps_time::0.8726985454559326.
# round::19, virtual_client::8, epoch::5, loss::0.002552082994952798, elps_time::0.8642427921295166.
# round::19, virtual_client::8, epoch::6, loss::0.0029493668116629124, elps_time::0.8537170886993408.
# round::19, virtual_client::8, epoch::7, loss::0.0014234925620257854, elps_time::0.8932373523712158.
# round::19, virtual_client::8, epoch::8, loss::0.0012996474979445338, elps_time::0.8807668685913086.
# round::19, virtual_client::8, epoch::9, loss::0.001802979502826929, elps_time::0.9027156829833984.
# round::19, virtual_client::9, epoch::0, loss::0.000685576000250876, elps_time::0.7291872501373291.
# round::19, virtual_client::9, epoch::1, loss::0.000554288737475872, elps_time::0.9728634357452393.
# round::19, virtual_client::9, epoch::2, loss::0.00018082413589581847, elps_time::0.9256911277770996.
# round::19, virtual_client::9, epoch::3, loss::1.5497195136049413e-06, elps_time::0.8977334499359131.
# round::19, virtual_client::9, epoch::4, loss::4.768360213347478e-06, elps_time::0.8635921478271484.
# round::19, virtual_client::9, epoch::5, loss::0.00041261743172071874, elps_time::0.7191994190216064.
# round::19, virtual_client::9, epoch::6, loss::1.2397689715726301e-05, elps_time::0.7316567897796631.
# round::19, virtual_client::9, epoch::7, loss::7.510157047363464e-06, elps_time::0.760673999786377.
# round::19, virtual_client::9, epoch::8, loss::1.6689286894688848e-06, elps_time::0.7572121620178223.
# round::19, virtual_client::9, epoch::9, loss::2.0503786799963564e-05, elps_time::0.8148488998413086.
# round::19 finished, test_acc::0.9839257001876831, elpsed time::107.72979998588562

# %%
acc_list
# Out:
# [0.9466853,
#  0.9309105,
#  0.9717452,
#  0.97464055,
#  0.9790335,
#  0.97853434,
#  0.9538738,
#  0.98003197,
#  0.9670527,
#  0.98152953,
#  0.9828275,
#  0.983127,
#  0.9833267,
#  0.9836262,
#  0.9836262,
#  0.9845248,
#  0.9836262,
#  0.9846246,
#  0.98442495,
#  0.9839257]

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(acc_list)),acc_list)
plt.xlabel("rounds")
plt.ylabel("test_acc")
plt.show()

# %%
# fedavg_seed0_beta_05 = [0.346146166324615,0.46675318479538,0.536541521549225,0.573682129383087,0.58316695690155,0.622603833675385,0.633386552333832,0.64367014169693,0.655051946640015,0.662739634513855,0.671625375747681,0.68140971660614,0.684205293655396,0.682208478450775,0.686900973320007,0.691293954849243,0.693390548229218,0.697683691978455,0.696984827518463]
# # fedprox_seed0_beta_05 = [0.35553115606308,0.466253995895386,0.536242008209229,0.566094219684601,0.57917332649231,0.606130182743073,0.626497626304626,0.631389796733856,0.646964848041534,0.655950486660004,0.667132616043091,0.677216470241547,0.680910527706146,0.68260782957077,0.686501622200012,0.687699675559998,0.689596652984619,0.697484016418457,0.695986449718475]
# moon_seed0_beta_05 = [0.360123813152313,0.475838661193848,0.539936125278473,0.576477646827698,0.584964036941528,0.61401754617691,0.622503995895386,0.638079047203064,0.65425318479538,0.658646166324616,0.665435314178467,0.676218032836914,0.683406531810761,0.67861419916153,0.686601459980011,0.687000811100006,0.692492008209229,0.697783529758453,0.698382616043091]
fedvir_seed0_beta_05 = [0.5548123, 0.5952476, 0.63977635, 0.6609425, 0.677516, 0.6963858, 0.7071685, 0.7157548, 0.71914935, 0.72853434, 0.73003197, 0.7345248, 0.7346246, 0.73722047, 0.73901755, 0.74021566, 0.74101436, 0.7433107, 0.74211264, 0.74271166]
plt.plot(range(19),fedavg_seed0_beta_05,label="FedAvg")
# plt.plot(range(19),fedprox_seed0_beta_05,label="FedProx")
# plt.plot(range(19),moon_seed0_beta_05,label="MOON")
plt.plot(range(20),fedvir_seed0_beta_05,label="FedVir(Ours)")
plt.xlabel("rounds")
plt.ylabel("test_acc")
plt.legend()
# # plt.savefig("fedDyn_beta05.png",dpi=330)
plt.show()

# %%
fedprox_seed0_beta_05=[0.162539929151535,0.211361825466156,0.267372190952301,0.296425729990005,0.26767173409462,0.343051105737686,0.351337850093842,0.348342657089233,0.352236419916153
,0.377396166324615,0.395866602659225,0.416833072900772,0.435902565717697,0.421126186847687,0.438897758722305,0.442891359329224,0.44928115606308,0.458965659141541
,0.453474432229996]

# %%
fedvir_seed0_beta_05_cifar100 = [0.319988, 0.36491615, 0.38578275, 0.39996007, 0.41134185, 0.4154353, 0.42272365, 0.4224241, 0.42501998, 0.42601836, 0.43011183, 0.4308107, 0.43190894, 0.4335064, 0.43370607, 0.43789935, 0.44029552, 0.4365016, 0.43869808, 0.4406949]

# %%
fedavg_seed0_beta_05 = [0.340455263853073,0.459065496921539,0.527855455875397,0.563997626304626,0.572683691978455,0.607927322387695,0.619109451770783,0.625998377799988,0.648861825466156,0.650459289550781,0.664337038993835,0.67082667350769,0.677416145801544,0.679113447666168,0.684604644775391,0.685902535915375,0.686501622200012,0.694688498973846,0.694788336753845]
len(fedavg_seed0_beta_05)
