# %%
import matplotlib.pyplot as plt
import numpy as np 
from matplotlib.ticker import MaxNLocator
# moon change from 5 to 10 with mu

# %%
# cifar10
fedavg_seed0_beta05 = [0.340455263853073,0.459065496921539,0.527855455875397,0.563997626304626,0.572683691978455,0.607927322387695,0.619109451770783,0.625998377799988,0.648861825466156,0.650459289550781,0.664337038993835,0.67082667350769,0.677416145801544,0.679113447666168,0.684604644775391,0.685902535915375,0.686501622200012,0.694688498973846,0.694788336753845,0.694788336753845]
fedprox_seed0_beta_05_mu01 = [0.33985623717308,0.450778752565384,0.524560689926147,0.561501622200012,0.570387363433838,0.606529533863068,0.621805131435394,0.63598245382309,0.647863447666168,0.655251622200012,0.66114217042923,0.669528782367706,0.676717281341553,0.682008802890778,0.681709289550781,0.682108640670776,0.687699675559998,0.691992819309235,0.692492008209229,0.692492008209229]
moon_seed0_beta_05_mu10 = [0.340954482555389,0.470347434282303,0.540535151958466,0.576477646827698,0.587959289550781,0.615315496921539,0.629193305969238,0.640575051307678,0.649760365486145,0.66114217042923,0.66603434085846,0.679512798786163,0.679313123226166,0.67981231212616,0.688598215579987,0.688698053359985,0.693989634513855,0.700179696083069,0.700778782367706,0.700778782367706]
FedVC_seed0_beta_05 = [0.5548123, 0.5952476, 0.63977635, 0.6609425, 0.677516, 0.6963858, 0.7071685, 0.7157548, 0.71914935, 0.72853434, 0.73003197, 0.7345248, 0.7346246, 0.73722047, 0.73901755, 0.74021566, 0.74101436, 0.7433107, 0.74211264, 0.74271166]

fedavg_seed0_beta01 = [0.311301916837692,0.37599840760231,0.430011987686157,0.463158935308456,0.480131775140762,0.507887363433838,0.534444868564606,0.54382985830307,0.545127809047699,0.561102211475372,0.573682129383087,0.574480831623077,0.584265172481537,0.590654969215393,0.596246004104614,0.599640548229218,0.601737201213837,0.605930507183075,0.611721217632294,0.611721217632294]
fedprox_seed0_beta_01_mu01 = [0.306010395288467,0.365015983581543,0.420327484607697,0.446785151958466,0.473941683769226,0.511082291603088,0.534944117069244,0.547623813152313,0.54303115606308,0.565495193004608,0.581669330596924,0.579772353172302,0.593350648880005,0.601537525653839,0.60473245382309,0.604532718658447,0.610323488712311,0.616912961006165,0.615515172481537,0.615515172481537]
moon_seed0_beta_01_mu10 = [0.303214848041534,0.371305912733078,0.428115010261536,0.462460070848465,0.492212474346161,0.520367383956909,0.535942494869232,0.548322677612305,0.553813874721527,0.564297139644623,0.5799720287323,0.583266794681549,0.597044706344605,0.600938498973846,0.606130182743073,0.60553115606308,0.609524786472321,0.614217281341553,0.618210852146149,0.618210852146149]
FedVC_seed0_beta_01 = [0.36222044, 0.40025958, 0.45626998, 0.51847047, 0.58117014, 0.6340855, 0.6701278, 0.692492, 0.70776755, 0.72274363, 0.73123, 0.735623, 0.742512, 0.740615, 0.74191296, 0.74490815, 0.7458067, 0.7455072, 0.7443091, 0.75]
# len(moon_seed0_beta_01_mu10)

# %%
rounds = range(1,21)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rounds, fedavg_seed0_beta05, marker='o', label="FedAvg")
plt.plot(rounds, fedprox_seed0_beta_05_mu01, marker='s', label="FedProx, $\mu={0.1}$")
plt.plot(rounds, moon_seed0_beta_05_mu10, marker='^', label="MOON, $\mu={10}$")
plt.plot(rounds, FedVC_seed0_beta_05, marker='d', label="FedVC(Ours)")
# Title and Labels
plt.title("Comparison of Algorithms - CIFAR-10 (beta=0.5)")
plt.xlabel("Rounds")
plt.ylabel("Test Accuracy")

# Set x-axis to integer values
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
# Legend
plt.legend(loc='lower right', prop={'size': 16})
# Grid and Background
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_facecolor('#f0f0f0')
# Save and Show Plot
plt.savefig("plot/105.png", dpi=330)
plt.show()

# %%
rounds = range(1,21)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rounds, fedavg_seed0_beta01, marker='o', label="FedAvg")
plt.plot(rounds, fedprox_seed0_beta_01_mu01, marker='s', label="FedProx, $\mu={0.1}$")
plt.plot(rounds, moon_seed0_beta_01_mu10, marker='^', label="MOON, $\mu={10}$")
plt.plot(rounds, FedVC_seed0_beta_01, marker='d', label="FedVC(Ours)")
# Title and Labels
plt.title("Comparison of Algorithms - CIFAR-10 (beta=0.1)")
plt.xlabel("Rounds")
plt.ylabel("Test Accuracy")

# Set x-axis to integer values
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
# Legend
plt.legend(loc='lower right', prop={'size': 16})
# Grid and Background
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_facecolor('#f0f0f0')
# Save and Show Plot
plt.savefig("plot/101.png", dpi=330)
plt.show()

# %%
# cifar100 here for moon mu is 5
fedavg_seed0_beta05 = [0.0833666101098061,0.125,0.158446490764618,0.186801120638847,0.216653361916542,0.234125405550003,0.251397758722305,0.264277160167694,0.271865010261536,0.276158154010773,0.28714057803154,0.290235608816147,0.298522353172302,0.304712474346161,0.311002403497696,0.317591845989227,0.323083072900772,0.324680507183075,0.331569492816925,0.331569492816925]
fedprox_seed0_beta_05_mu01 = [0.084464855492115,0.124900162220001,0.155750796198845,0.181409746408463,0.207268372178078,0.222344249486923,0.240215659141541,0.250399351119995,0.261082261800766,0.269069492816925,0.281749188899994,0.289836257696152,0.295127809047699,0.300619006156921,0.308905750513077,0.306509584188461,0.312599837779999,0.316593438386917,0.322983235120773,0.322983235120773]
moon_seed0_beta_05_mu10 = [0.0804712474346161,0.123901754617691,0.157947286963463,0.183206871151924,0.209365010261536,0.226537540555,0.23831869661808,0.255191683769226,0.267272353172302,0.266972839832306,0.281749188899994,0.287240415811539,0.293929725885391,0.297823488712311,0.307507991790771,0.311601430177689,0.311801105737686,0.320786744356155,0.322284340858459,0.322284340858459]
FedVC_seed0_beta_05 = [0.319988, 0.36491615, 0.38578275, 0.39996007, 0.41134185, 0.4154353, 0.42272365, 0.4224241, 0.42501998, 0.42601836, 0.43011183, 0.4308107, 0.43190894, 0.4335064, 0.43370607, 0.43789935, 0.44029552, 0.4365016, 0.43869808, 0.4406949]

fedavg_seed0_beta01 = [0.0459265187382698,0.0802715644240379,0.10742811858654,0.135682910680771,0.161242008209229,0.179412946105003,0.199780344963074,0.211261987686157,0.225139781832695,0.233526363968849,0.243610218167305,0.256289929151535,0.26667332649231,0.272464066743851,0.277555912733078,0.285742819309235,0.292232424020767,0.291733235120773,0.298722058534622,0.298722058534622]
fedprox_seed0_beta_01_mu01 = [0.0455271564424038,0.0784744396805763,0.103734023869038,0.126297920942307,0.14546725153923,0.16014376282692,0.173921719193459,0.192292332649231,0.206569492816925,0.210762783885002,0.229732424020767,0.235123798251152,0.241114214062691,0.247503995895386,0.252695679664612,0.265874594449997,0.26946884393692,0.277056723833084,0.275858640670776,0.275858640670776]
moon_seed0_beta_01_mu10 = [0.049520768225193,0.0835662931203842,0.111222043633461,0.134185299277306,0.157747596502304,0.173921719193459,0.197184503078461,0.209864214062691,0.223043128848076,0.231230035424232,0.235123798251152,0.246605426073074,0.258286744356155,0.259584665298462,0.267971247434616,0.278654158115387,0.280650973320007,0.287040740251541,0.28714057803154,0.28714057803154]
FedVC_seed0_beta_01 = [0.21815096, 0.28674123, 0.3263778, 0.35213658, 0.38388577, 0.39716452, 0.41164136, 0.41673324, 0.42222443, 0.42861423, 0.4310104, 0.43340656, 0.4365016, 0.43630192, 0.4392971, 0.43949682, 0.44089457, 0.4389976, 0.44329074, 0.44448882]

# %%
rounds = range(1,21)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rounds, fedavg_seed0_beta05, marker='o', label="FedAvg")
plt.plot(rounds, fedprox_seed0_beta_05_mu01, marker='s', label="FedProx, $\mu={0.1}$")
plt.plot(rounds, moon_seed0_beta_05_mu10, marker='^', label="MOON, $\mu={10}$")
plt.plot(rounds, FedVC_seed0_beta_05, marker='d', label="FedVC(Ours)")
# Title and Labels
plt.title("Comparison of Algorithms - CIFAR-100 (beta=0.5)")
plt.xlabel("Rounds")
plt.ylabel("Test Accuracy")

# Set x-axis to integer values
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
# Legend
plt.legend(loc='lower right', prop={'size': 16})
# Grid and Background
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_facecolor('#f0f0f0')
# Save and Show Plot
plt.savefig("plot/1005.png", dpi=330)
plt.show()

# %%
rounds = range(1,21)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rounds, fedavg_seed0_beta01, marker='o', label="FedAvg")
plt.plot(rounds, fedprox_seed0_beta_01_mu01, marker='s', label="FedProx, $\mu={0.1}$")
plt.plot(rounds, moon_seed0_beta_01_mu10, marker='^', label="MOON, $\mu={10}$")
plt.plot(rounds, FedVC_seed0_beta_01, marker='d', label="FedVC(Ours)")
# Title and Labels
plt.title("Comparison of Algorithms - CIFAR-100 (beta=0.1)")
plt.xlabel("Rounds")
plt.ylabel("Test Accuracy")

# Set x-axis to integer values
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
# Legend
plt.legend(loc='lower right', prop={'size': 16})
# Grid and Background
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_facecolor('#f0f0f0')
# Save and Show Plot
plt.savefig("plot/1001.png", dpi=330)
plt.show()

# %%
# mnist
fedavg_seed0_beta05 = []
fedprox_seed0_beta_05_mu01 = []
moon_seed0_beta_05_mu10 = []
FedVC_seed0_beta_05 = [0.9466853, 0.9309105, 0.9717452, 0.97464055, 0.9790335, 0.97853434, 0.9538738, 0.98003197, 0.9670527, 0.98152953, 0.9828275, 0.983127, 0.9833267, 0.9836262, 0.9836262, 0.9845248, 0.9836262, 0.9846246, 0.98442495, 0.9839257]

fedavg_seed0_beta01 = []
fedprox_seed0_beta_01_mu01 = []
moon_seed0_beta_01_mu10 = []
FedVC_seed0_beta_01 = [0.88847846, 0.9481829, 0.9635583, 0.96805114, 0.9720447, 0.97384185, 0.975639, 0.97683704, 0.97723645, 0.978135, 0.978734, 0.97933304, 0.9796326, 0.9759385, 0.9789337, 0.98053116, 0.9801318, 0.980631, 0.98083067, 0.98083067]

# %%
# plt.plot(range(19),fedavg_seed0_beta05,label="FedAvg")
# plt.plot(range(19),fedprox_seed0_beta_05_mu01,label="FedProx")
# plt.plot(range(19),moon_seed0_beta_05_mu10,label="MOON")
plt.plot(range(20),FedVC_seed0_beta_05,label="FedVC(Ours)")
plt.title("mnist beta=0.5")
plt.xlabel("rounds")
plt.ylabel("test_acc")
plt.legend()
# plt.savefig(".png",dpi=330)
plt.show()

# %%
# plt.plot(range(19),fedavg_seed0_beta01,label="FedAvg")
# plt.plot(range(19),fedprox_seed0_beta_01_mu01,label="FedProx")
# plt.plot(range(19),moon_seed0_beta_01_mu10,label="MOON")
plt.plot(range(20),FedVC_seed0_beta_01,label="FedVC(Ours)")
plt.title("mnist beta=0.1")
plt.xlabel("rounds")
plt.ylabel("test_acc")
plt.legend()
# plt.savefig(".png",dpi=330)
plt.show()

# %%
fedvc_seed0_beta_05_cifar10_virtual_20 = [0.546226, 0.6011382, 0.65195686, 0.6767173, 0.6996805, 0.7126597, 0.7224441, 0.72723645, 0.7311302, 0.73322684, 0.73801917, 0.73901755, 0.74460864, 0.7422125, 0.7451078, 0.7483027, 0.7417133, 0.74371004, 0.7486022, 0.7447085]
fedvc_seed0_beta_05_cifar10_virtual_10 = [0.47553915, 0.5369409, 0.5823682, 0.6159145, 0.6450679, 0.66054314, 0.6761182, 0.689397, 0.70197684, 0.71285945, 0.7202476, 0.72184503, 0.73003197, 0.7336262, 0.73522365, 0.740016, 0.74161345, 0.74161345, 0.7434105, 0.745008]
fedvc_seed0_beta_05_cifar10_virtual_5 = [0.4749401, 0.51527554, 0.57008785, 0.59784347, 0.6257987, 0.6457668, 0.65884584, 0.66932905, 0.6763179, 0.6853035, 0.68909746, 0.69289136, 0.6976837, 0.7058706, 0.7107628, 0.7157548, 0.7157548, 0.716853, 0.72384185, 0.72304314]
fedvc_seed0_beta_05_cifar10_virtual_30 = [0.57288337, 0.63678116, 0.67022765, 0.6818091, 0.7109625, 0.7197484, 0.72523963, 0.73053116, 0.72853434, 0.73472446, 0.73771966, 0.73871803, 0.73003197, 0.7443091, 0.74570686, 0.7453075, 0.74291134, 0.7502995, 0.749401, 0.75409347]
fedvc_seed0_beta_05_cifar10_virtual_1 = [0.5126797, 0.5349441, 0.5910543, 0.60303515, 0.62040734, 0.63148963, 0.63807905, 0.6485623, 0.6500599, 0.65634984, 0.6698283, 0.6654353, 0.67621803, 0.67272365, 0.6763179, 0.6793131, 0.6801118, 0.6838059, 0.6818091, 0.6789137]

# %%
rounds = range(1,21)
# Plotting
plt.figure(figsize=(10, 6))

plt.plot(rounds, fedvc_seed0_beta_05_cifar10_virtual_1, marker='v', label="NumVirtual_1")
plt.plot(rounds, fedvc_seed0_beta_05_cifar10_virtual_5, marker='^', label="NumVirtual_5")
plt.plot(rounds, fedvc_seed0_beta_05_cifar10_virtual_10, marker='s', label="NumVirtual_10")
plt.plot(rounds, fedvc_seed0_beta_05_cifar10_virtual_20, marker='o', label="NumVirtual_20")
plt.plot(rounds, fedvc_seed0_beta_05_cifar10_virtual_30, marker='d', label="NumVirtual_30")
# Title and Labels
plt.title("Comparison of Virtual Client Num - CIFAR-10 (beta=0.5, NumReal=20)")
plt.xlabel("Rounds")
plt.ylabel("Test Accuracy")

# Set x-axis to integer values
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
# Legend
plt.legend(loc='lower right', prop={'size': 16})
# Grid and Background
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_facecolor('#f0f0f0')
# Save and Show Plot
plt.savefig("plot/HyperParam.png", dpi=330)
plt.show()

# %%
fedvc_seed0_beta_01_cifar10_virtual_5 = [0.27486023, 0.34664536, 0.41253993, 0.47354233, 0.5163738, 0.54822284, 0.57947284, 0.6045327, 0.6311901, 0.654353, 0.6686302, 0.6797125, 0.6860024, 0.6948882, 0.6966853, 0.7075679, 0.70916533, 0.71026355, 0.71555513, 0.7239417]
fedvc_seed0_beta_01_cifar10_virtual_10 = [0.3467452, 0.3990615, 0.4124401, 0.44798324, 0.5451278, 0.6147165, 0.6623403, 0.69598645, 0.7125599, 0.7197484, 0.72713655, 0.73132986, 0.735623, 0.73771966, 0.7391174, 0.74371004, 0.7436102, 0.73552316, 0.74690497, 0.74620605]
fedvc_seed0_beta_01_cifar10_virtual_20 = [0.4597644, 0.54373, 0.578774, 0.64476836, 0.69628596, 0.71335864, 0.7239417, 0.73182905, 0.7314297, 0.7323283, 0.73652154, 0.7391174, 0.7383187, 0.7409145, 0.7392173, 0.7455072, 0.74600637, 0.743111, 0.74740416, 0.7501997]
fedvc_seed0_beta_01_cifar10_virtual_30 = [0.50848645, 0.58915734, 0.66164136, 0.701278, 0.72084665, 0.7248403, 0.7314297, 0.7370208, 0.74191296, 0.7438099, 0.7422125, 0.7455072, 0.7463059, 0.7483027, 0.74820286, 0.7507987, 0.75129795, 0.7451078, 0.75309503, 0.7559904]
fedvc_seed0_beta_01_cifar10_virtual_1 =  [0.32647765, 0.3779952, 0.41583467, 0.44458866, 0.4630591, 0.48392573, 0.48582268, 0.51098245, 0.52416134, 0.5421326, 0.5446286, 0.5576078, 0.5592053, 0.56649363, 0.57038736, 0.5731829, 0.57557905, 0.58117014, 0.5888578, 0.58176917]

# %%
rounds = range(1,21)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(rounds, fedvc_seed0_beta_01_cifar10_virtual_1, marker='v', label="NumVirtual_1")
plt.plot(rounds, fedvc_seed0_beta_01_cifar10_virtual_5, marker='^', label="NumVirtual_5")
plt.plot(rounds, fedvc_seed0_beta_01_cifar10_virtual_10, marker='s', label="NumVirtual_10")
plt.plot(rounds, fedvc_seed0_beta_01_cifar10_virtual_20, marker='o', label="NumVirtual_20")
plt.plot(rounds, fedvc_seed0_beta_01_cifar10_virtual_30, marker='d', label="NumVirtual_30")
# Title and Labels
plt.title("Comparison of Virtual Client Num - CIFAR-10 (beta=0.1, NumReal=20)")
plt.xlabel("Rounds")
plt.ylabel("Test Accuracy")

# Set x-axis to integer values
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
# Legend
plt.legend(loc='lower right', prop={'size': 16})
# Grid and Background
plt.grid(True, linestyle='--', alpha=0.7)
plt.gca().set_facecolor('#f0f0f0')
# Save and Show Plot
plt.savefig("plot/HyperParam_01.png", dpi=330)
plt.show()
